# %% [markdown]
# # Datasets to the rescue!

# %%
# !pip install requests
# !pip install python-dotenv

# %%
import requests
from dotenv import dotenv_values
import time
import math
from pathlib import Path
import pandas as pd
from tqdm.notebook import tqdm
from datasets import load_dataset

# %%
url = "https://api.github.com/repos/huggingface/datasets/issues?page=1&per_page=1"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'url': 'https://api.github.com/repos/huggingface/datasets/issues/6322',
#   'repository_url': 'https://api.github.com/repos/huggingface/datasets',
#   'labels_url': 'https://api.github.com/repos/huggingface/datasets/issues/6322/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/huggingface/datasets/issues/6322/comments',
#   'events_url': 'https://api.github.com/repos/huggingface/datasets/issues/6322/events',
#   'html_url': 'https://github.com/huggingface/datasets/pull/6322',
#   'id': 1952947461,
#   'node_id': 'PR_kwDODunzps5dT5vG',
#   'number': 6322,
#   'title': 'Fix regex `get_data_files` formatting for base paths',
#   'user': {'login': 'ZachNagengast',
#    'id': 1981179,
#    'node_id': 'MDQ6VXNlcjE5ODExNzk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1981179?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ZachNagengast',
#    'html_url': 'https://github.com/ZachNagengast',
#    'followers_url': 'https://api.github.com/users/ZachNagengast/followers',
#    'following_url': 'https://api.github.com/users/ZachNagengast/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ZachNagengast/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ZachNagengast/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ZachNagengast/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ZachNagengast/orgs',
#    'repos_url': 'https://api.github.com/users/ZachNagengast/repos',
#    'events_url': 'https://api.github.com/users/ZachNagengast/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ZachNagengast/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-10-19T19:45:10Z',
#   'updated_at': '2023-10-19T19:46:26Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/huggingface/datasets/pulls/6322',
#    'html_url': 'https://github.com/huggingface/datasets/pull/6322',
#    'diff_url': 'https://github.com/huggingface/datasets/pull/6322.diff',
#    'patch_url': 'https://github.com/huggingface/datasets/pull/6322.patch',
#    'merged_at': None},
#   'body': 'With this pr https://github.com/huggingface/datasets/pull/6309, it is formatting the entire base path into regex, which results in the undesired formatting error `doesn\'t match the pattern` because of the line in `glob_pattern_to_regex`: `.replace("//", "/")`:\r\n- Input: `hf://datasets/...`\r\n- Output: `hf:/datasets/...`\r\n\r\nThis fix will only convert the `split_pattern` to regex and keep the `base_path` unchanged.\r\n\r\ncc @albertvillanova hopefully this still works with your implementation',
#   'reactions': {'url': 'https://api.github.com/repos/huggingface/datasets/issues/6322/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/huggingface/datasets/issues/6322/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
config = dotenv_values(".env")

# %%
headers = {"Authorization": f"token {config['GITHUB_TOKEN']}"}

# %%
def fetch_issues(
    owner="huggingface",
    repo="datasets",
    num_issues=10_000,
    rate_limit=5_000,
    issues_path=Path('.'),
):
    
    if not issues_path.is_dir():
        issues_path.mkdir(exist_ok=True)

    batch = []
    all_issues = []
    per_page = 100 # Number of issues to return per page
    num_pages = math.ceil(num_issues / per_page)
    base_url = "https://api.github.com/repos"

    for page in tqdm(range(num_pages)):
        query = f"issues?page={page}&per_page={per_page}&state=all"
        issues = requests.get(f"{base_url}/{owner}/{repo}/{query}", headers=headers)
        batch.extend(issues.json())

        if len(batch) > rate_limit and len(all_issues) < num_issues:
            all_issues.extend(batch)
            batch = []
            print(f"Reached Github rate limit. Sleeping for one hour ...")
            time.sleep(60 * 60 + 1)

    all_issues.extend(batch)
    df = pd.DataFrame.from_records(all_issues)
    df.to_json(f"{issues_path}/{repo}-issues.jsonl", orient="records", lines=True)
    print(f"Downloaded all the issues for {repo}! Dataset stored at {issues_path}/{repo}-issues.jsonl")

# %%
Path("./datasets-issues.jsonl").exists()
# Out:
# True

# %%
if not Path("./datasets-issues.jsonl").exists(): fetch_issues()

# %%
df = pd.read_json("./datasets-issues.jsonl", orient="records", lines=True)

# %%
df.transpose().head(30)
# Out:
#                                                                        0     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1943466532
# node_id                                                  I_kwDODunzps5z1vIk
# number                                                                 6303
# title                              Parquet uploads off-by-one naming scheme
# user                      {'login': 'ZachNagengast', 'id': 1981179, 'nod...
# labels                                                                   []
# state                                                                  open
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-10-14 18:31:03+00:00
# updated_at                                        2023-10-14 18:31:03+00:00
# closed_at                                                               NaT
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\n\nI noticed this numberi...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1942096078
# node_id                                                  I_kwDODunzps5zwgjO
# number                                                                 6302
# title                     ArrowWriter/ParquetWriter `write` method does ...
# user                      {'login': 'Rassibassi', 'id': 2855550, 'node_i...
# labels                                                                   []
# state                                                                  open
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-10-13 14:43:36+00:00
# updated_at                                        2023-10-13 14:43:36+00:00
# closed_at                                                               NaT
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\n\nAn example from [1], d...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        2     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6301
# id                                                               1940183999
# node_id                                                 PR_kwDODunzps5cpPVh
# number                                                                 6301
# title                                    Unpin `tensorflow` maximum version
# user                      {'login': 'mariosasko', 'id': 47462742, 'node_...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2023-10-12 14:58:07+00:00
# updated_at                                        2023-10-12 15:58:20+00:00
# closed_at                                         2023-10-12 15:49:54+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                         Removes the temporary pin introduced in #6264
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        3     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6300
# id                                                               1940153432
# node_id                                                 PR_kwDODunzps5cpIoG
# number                                                                 6300
# title                                           Unpin `jax` maximum version
# user                      {'login': 'mariosasko', 'id': 47462742, 'node_...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  6
# created_at                                        2023-10-12 14:42:40+00:00
# updated_at                                        2023-10-12 16:37:55+00:00
# closed_at                                         2023-10-12 16:28:57+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                                                 fix #6299\r\nfix #6202
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        4     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1939649238
# node_id                                                  I_kwDODunzps5znLLW
# number                                                                 6299
# title                                     Support for newer versions of JAX
# user                      {'login': 'ddrous', 'id': 25456859, 'node_id':...
# labels                    [{'id': 1935892871, 'node_id': 'MDU6TGFiZWwxOT...
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-10-12 10:03:46+00:00
# updated_at                                        2023-10-12 16:28:59+00:00
# closed_at                                         2023-10-12 16:28:59+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Feature request\r\n\r\nHi,\r\n\r\nI like y...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        5     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6298
# id                                                               1938797389
# node_id                                                 PR_kwDODunzps5ckg6j
# number                                                                 6298
# title                                               Doc readme improvements
# user                      {'login': 'mariosasko', 'id': 47462742, 'node_...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-11 21:51:12+00:00
# updated_at                                        2023-10-12 12:47:15+00:00
# closed_at                                         2023-10-12 12:38:19+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      Changes in the doc READMe:\r\n* adds two new s...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        6     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6297
# id                                                               1938752707
# node_id                                                 PR_kwDODunzps5ckXBa
# number                                                                 6297
# title                                                      Fix ArrayXD cast
# user                      {'login': 'mariosasko', 'id': 47462742, 'node_...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-11 21:14:59+00:00
# updated_at                                        2023-10-13 13:54:00+00:00
# closed_at                                         2023-10-13 13:45:30+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                                                             Fix #6291
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        7     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6296
# id                                                               1938453845
# node_id                                                 PR_kwDODunzps5cjUs1
# number                                                                 6296
# title                         Move `exceptions.py` to `utils/exceptions.py`
# user                      {'login': 'mariosasko', 'id': 47462742, 'node_...
# labels                                                                   []
# state                                                                  open
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-11 18:28:00+00:00
# updated_at                                        2023-10-12 13:54:29+00:00
# closed_at                                                               NaT
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      I didn't notice the path while reviewing the P...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        8     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6295
# id                                                               1937362102
# node_id                                                 PR_kwDODunzps5cfiW8
# number                                                                 6295
# title                        Fix parquet columns argument in streaming mode
# user                      {'login': 'lhoestq', 'id': 42851186, 'node_id'...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2023-10-11 10:01:01+00:00
# updated_at                                        2023-10-11 16:30:24+00:00
# closed_at                                         2023-10-11 16:21:36+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      It was failing when there's a DatasetInfo with...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        9     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1937359605
# node_id                                                  I_kwDODunzps5zecL1
# number                                                                 6294
# title                     IndexError: Invalid key is out of bounds for s...
# user                      {'login': 'ZYM66', 'id': 61892155, 'node_id': ...
# labels                                                                   []
# state                                                                  open
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-11 09:59:38+00:00
# updated_at                                        2023-10-11 13:10:31+00:00
# closed_at                                                               NaT
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\n\nI am encountering an `...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   NaN
# pull_request                                                           None
#
#                           ...  \
# url                       ...
# repository_url            ...
# labels_url                ...
# comments_url              ...
# events_url                ...
# html_url                  ...
# id                        ...
# node_id                   ...
# number                    ...
# title                     ...
# user                      ...
# labels                    ...
# state                     ...
# locked                    ...
# assignee                  ...
# assignees                 ...
# milestone                 ...
# comments                  ...
# created_at                ...
# updated_at                ...
# closed_at                 ...
# author_association        ...
# active_lock_reason        ...
# body                      ...
# reactions                 ...
# timeline_url              ...
# performed_via_github_app  ...
# state_reason              ...
# draft                     ...
# pull_request              ...
#
#                                                                        6269  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                    https://github.com/huggingface/datasets/pull/10
# id                                                                603909327
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA2NjAxNzQ2
# number                                                                   10
# title                     Name json file "squad.json" instead of "squad....
# user                      {'login': 'patrickvonplaten', 'id': 23423619, ...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-21 11:04:28+00:00
# updated_at                                        2022-10-04 09:31:44+00:00
# closed_at                                         2020-04-21 20:48:06+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        6270  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/9
# id                                                                603894874
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA2NTkwMDQw
# number                                                                    9
# title                                                   [Clean up] Datasets
# user                      {'login': 'patrickvonplaten', 'id': 23423619, ...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2020-04-21 10:39:56+00:00
# updated_at                                        2022-10-04 09:31:42+00:00
# closed_at                                         2020-04-21 20:49:58+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      Clean up `nlp/datasets` folder. \r\n\r\nAs I u...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        6271  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/8
# id                                                                601783243
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA0OTg0NDUz
# number                                                                    8
# title                     Fix issue 6: error when the citation is missin...
# user                      {'login': 'jplu', 'id': 959590, 'node_id': 'MD...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-17 08:04:26+00:00
# updated_at                                        2020-04-29 09:27:11+00:00
# closed_at                                         2020-04-20 13:24:12+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        6272  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/7
# id                                                                601780534
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA0OTgyMzA2
# number                                                                    7
# title                                     Fix issue 5: allow empty datasets
# user                      {'login': 'jplu', 'id': 959590, 'node_id': 'MD...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-17 07:59:56+00:00
# updated_at                                        2020-04-29 09:27:13+00:00
# closed_at                                         2020-04-20 13:23:48+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        6273  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/6
# id                                                                600330836
# node_id                                            MDU6SXNzdWU2MDAzMzA4MzY=
# number                                                                    6
# title                     Error when citation is not given in the Datase...
# user                      {'login': 'jplu', 'id': 959590, 'node_id': 'MD...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-15 14:14:54+00:00
# updated_at                                        2020-04-29 09:23:22+00:00
# closed_at                                         2020-04-29 09:23:22+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      The following error is raised when the `citati...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        6274  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/5
# id                                                                600295889
# node_id                                            MDU6SXNzdWU2MDAyOTU4ODk=
# number                                                                    5
# title                                      ValueError when a split is empty
# user                      {'login': 'jplu', 'id': 959590, 'node_id': 'MD...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-15 13:25:13+00:00
# updated_at                                        2020-04-29 09:23:05+00:00
# closed_at                                         2020-04-29 09:23:05+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      When a split is empty either TEST, VALIDATION ...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        6275  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/4
# id                                                                600185417
# node_id                                            MDU6SXNzdWU2MDAxODU0MTc=
# number                                                                    4
# title                     [Feature] Keep the list of labels of a dataset...
# user                      {'login': 'jplu', 'id': 959590, 'node_id': 'MD...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  6
# created_at                                        2020-04-15 10:17:10+00:00
# updated_at                                        2020-07-08 16:59:46+00:00
# closed_at                                         2020-05-04 06:11:57+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      It would be useful to keep the list of the lab...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        6276  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/3
# id                                                                600180050
# node_id                                            MDU6SXNzdWU2MDAxODAwNTA=
# number                                                                    3
# title                                        [Feature] More dataset outputs
# user                      {'login': 'jplu', 'id': 959590, 'node_id': 'MD...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-15 10:08:14+00:00
# updated_at                                        2020-05-04 06:12:27+00:00
# closed_at                                         2020-05-04 06:12:27+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      Add the following dataset outputs:\r\n\r\n- Sp...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        6277  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/2
# id                                                                599767671
# node_id                                            MDU6SXNzdWU1OTk3Njc2NzE=
# number                                                                    2
# title                                         Issue to read a local dataset
# user                      {'login': 'jplu', 'id': 959590, 'node_id': 'MD...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  5
# created_at                                        2020-04-14 18:18:51+00:00
# updated_at                                        2020-05-11 18:55:23+00:00
# closed_at                                         2020-05-11 18:55:22+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      Hello,\r\n\r\nAs proposed by @thomwolf, I open...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        6278
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/1
# id                                                                599457467
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDAzMDk1NDYw
# number                                                                    1
# title                                        changing nlp.bool to nlp.bool_
# user                      {'login': 'mariamabarham', 'id': 38249783, 'no...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-14 10:18:02+00:00
# updated_at                                        2022-10-04 09:31:40+00:00
# closed_at                                         2020-04-14 12:01:40+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
# [30 rows x 6279 columns]

# %% [markdown]
# It seems there is an issue with `load_dataset`: https://github.com/huggingface/datasets/issues/5422

# %% [markdown]
# Therefore lets use the suggestion here https://github.com/huggingface/datasets/issues/5422#issuecomment-1718035537

# %%
from datasets import Dataset
issues_dataset = Dataset.from_pandas(df)
issues_dataset
# Out:
# Dataset({
#     features: ['url', 'repository_url', 'labels_url', 'comments_url', 'events_url', 'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels', 'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments', 'created_at', 'updated_at', 'closed_at', 'author_association', 'active_lock_reason', 'body', 'reactions', 'timeline_url', 'performed_via_github_app', 'state_reason', 'draft', 'pull_request'],
#     num_rows: 6279
# })

# %%
sample = issues_dataset.shuffle(seed=666).select(range(3))

# %%
for url, pr in zip(sample['html_url'], sample['pull_request']):
    print(f">> URL: {url}")
    print(f">> Pull request: {pr}\n")
# Out:
# >> URL: https://github.com/huggingface/datasets/issues/1965
# >> Pull request: None
#
# >> URL: https://github.com/huggingface/datasets/pull/3472
# >> Pull request: {'diff_url': 'https://github.com/huggingface/datasets/pull/3472.diff', 'html_url': 'https://github.com/huggingface/datasets/pull/3472', 'merged_at': '2021-12-22T16:52:52Z', 'patch_url': 'https://github.com/huggingface/datasets/pull/3472.patch', 'url': 'https://api.github.com/repos/huggingface/datasets/pulls/3472'}
#
# >> URL: https://github.com/huggingface/datasets/pull/892
# >> Pull request: {'diff_url': 'https://github.com/huggingface/datasets/pull/892.diff', 'html_url': 'https://github.com/huggingface/datasets/pull/892', 'merged_at': '2020-11-27T18:08:44Z', 'patch_url': 'https://github.com/huggingface/datasets/pull/892.patch', 'url': 'https://api.github.com/repos/huggingface/datasets/pulls/892'}

# %%
issues_dataset = issues_dataset.map(
    lambda x: {"is_pull_request": False if x["pull_request"] is None else True}
)
# Out:
# Map:   0%|          | 0/6279 [00:00<?, ? examples/s]

# %%
issues_dataset_closed = issues_dataset.filter(lambda x: x["is_pull_request"] == False and x['state'] == 'closed')
# Out:
# Filter:   0%|          | 0/6279 [00:00<?, ? examples/s]

# %%
issues_dataset_closed.set_format("pandas")

# %%
issues_dataset_closed
# Out:
# Dataset({
#     features: ['url', 'repository_url', 'labels_url', 'comments_url', 'events_url', 'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels', 'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments', 'created_at', 'updated_at', 'closed_at', 'author_association', 'active_lock_reason', 'body', 'reactions', 'timeline_url', 'performed_via_github_app', 'state_reason', 'draft', 'pull_request', 'is_pull_request'],
#     num_rows: 1946
# })

# %%
issues_dataset_closed_df = issues_dataset_closed[:]

# %%
issues_dataset_closed_df.transpose().head(30)
# Out:
#                                                                        0     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1939649238
# node_id                                                  I_kwDODunzps5znLLW
# number                                                                 6299
# title                                     Support for newer versions of JAX
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                    [{'color': 'a2eeef', 'default': True, 'descrip...
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-10-12 10:03:46+00:00
# updated_at                                        2023-10-12 16:28:59+00:00
# closed_at                                         2023-10-12 16:28:59+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Feature request\r\n\r\nHi,\r\n\r\nI like y...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1937238047
# node_id                                                  I_kwDODunzps5zd-gf
# number                                                                 6293
# title                     Choose columns to stream parquet data in strea...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                    [{'color': 'd73a4a', 'default': True, 'descrip...
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-10-11 08:59:36+00:00
# updated_at                                        2023-10-11 16:21:38+00:00
# closed_at                                         2023-10-11 16:21:38+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      Currently passing columns= to load_dataset in ...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        2     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1936129871
# node_id                                                  I_kwDODunzps5zZv9P
# number                                                                 6291
# title                     Casting type from Array2D int to Array2D float...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-10 20:10:10+00:00
# updated_at                                        2023-10-13 13:45:31+00:00
# closed_at                                         2023-10-13 13:45:31+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\r\n\r\nI am on a school p...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        3     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1932758192
# node_id                                                  I_kwDODunzps5zM4yw
# number                                                                 6287
# title                                          map() not recognizing "text"
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-09 10:27:30+00:00
# updated_at                                        2023-10-11 20:28:45+00:00
# closed_at                                         2023-10-11 20:28:45+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\n\nThe [map() documentati...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        4     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1929551712
# node_id                                                  I_kwDODunzps5zAp9g
# number                                                                 6284
# title                     Add Belebele multiple-choice machine reading c...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                    [{'color': 'a2eeef', 'default': True, 'descrip...
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-06 06:58:03+00:00
# updated_at                                        2023-10-06 13:26:51+00:00
# closed_at                                         2023-10-06 13:26:51+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Feature request\n\nBelebele is a multiple-...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        5     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1927044546
# node_id                                                  I_kwDODunzps5y3F3C
# number                                                                 6277
# title                     FileNotFoundError: Couldn't find a module scri...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-04 22:01:25+00:00
# updated_at                                        2023-10-08 17:05:46+00:00
# closed_at                                         2023-10-08 17:05:46+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\n\nI'm encountering a "Fi...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        6     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1921354680
# node_id                                                  I_kwDODunzps5yhYu4
# number                                                                 6275
# title                                    Would like to Contribute a dataset
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-02 07:00:21+00:00
# updated_at                                        2023-10-10 16:27:54+00:00
# closed_at                                         2023-10-10 16:27:54+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      I have a dataset of 2500 images that can be us...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        7     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1921036328
# node_id                                                  I_kwDODunzps5ygLAo
# number                                                                 6274
# title                     FileNotFoundError for dataset with multiple bu...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-01 23:45:56+00:00
# updated_at                                        2023-10-02 20:09:38+00:00
# closed_at                                         2023-10-02 20:09:38+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\n\nWhen there is only one...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        8     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1920329373
# node_id                                                  I_kwDODunzps5ydead
# number                                                                 6270
# title                     Dataset.from_generator raises with sharded gen...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  6
# created_at                                        2023-09-30 16:50:06+00:00
# updated_at                                        2023-10-11 20:29:12+00:00
# closed_at                                         2023-10-11 20:29:11+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\n\nAccording to the docs ...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        9     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1914951043
# node_id                                                  I_kwDODunzps5yI9WD
# number                                                                 6263
# title                     CI is broken: ImportError: cannot import name ...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                    [{'color': 'd73a4a', 'default': True, 'descrip...
# state                                                                closed
# locked                                                                False
# assignee                  {'avatar_url': 'https://avatars.githubusercont...
# assignees                 [{'avatar_url': 'https://avatars.githubusercon...
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-09-27 08:12:05+00:00
# updated_at                                        2023-09-27 08:36:40+00:00
# closed_at                                         2023-09-27 08:36:40+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      Python 3.10 CI is broken for `test_py310`.\r\n...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                           ...  \
# url                       ...
# repository_url            ...
# labels_url                ...
# comments_url              ...
# events_url                ...
# html_url                  ...
# id                        ...
# node_id                   ...
# number                    ...
# title                     ...
# user                      ...
# labels                    ...
# state                     ...
# locked                    ...
# assignee                  ...
# assignees                 ...
# milestone                 ...
# comments                  ...
# created_at                ...
# updated_at                ...
# closed_at                 ...
# author_association        ...
# active_lock_reason        ...
# body                      ...
# reactions                 ...
# timeline_url              ...
# performed_via_github_app  ...
# state_reason              ...
# draft                     ...
# pull_request              ...
#
#                                                                        1936  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                                618632573
# node_id                                            MDU6SXNzdWU2MTg2MzI1NzM=
# number                                                                  117
# title                          ❓ How to remove specific rows of a dataset ?
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  4
# created_at                                        2020-05-15 01:25:06+00:00
# updated_at                                        2022-07-15 08:36:44+00:00
# closed_at                                         2020-05-15 07:04:32+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      I saw on the [example notebook](https://colab....
# reactions                 {'+1': 1, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1937  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                                618628264
# node_id                                            MDU6SXNzdWU2MTg2MjgyNjQ=
# number                                                                  116
# title                     🐛 Trying to use ROUGE metric : pyarrow.lib.Arr...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                    [{'color': '25b21e', 'default': False, 'descri...
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  5
# created_at                                        2020-05-15 01:12:06+00:00
# updated_at                                        2020-05-28 23:43:07+00:00
# closed_at                                         2020-05-28 23:43:07+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      I'm trying to use rouge metric.\r\n\r\nI have ...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1938  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                                618615855
# node_id                                            MDU6SXNzdWU2MTg2MTU4NTU=
# number                                                                  115
# title                     AttributeError: 'dict' object has no attribute...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                  {'avatar_url': 'https://avatars.githubusercont...
# assignees                 [{'avatar_url': 'https://avatars.githubusercon...
# milestone                                                              None
# comments                                                                  2
# created_at                                        2020-05-15 00:29:47+00:00
# updated_at                                        2020-05-17 13:11:00+00:00
# closed_at                                         2020-05-17 13:11:00+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      I'm trying to access the information of CNN/DM...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1939  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                                618611310
# node_id                                            MDU6SXNzdWU2MTg2MTEzMTA=
# number                                                                  114
# title                                         Couldn't reach CNN/DM dataset
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2020-05-15 00:16:17+00:00
# updated_at                                        2020-05-15 00:19:52+00:00
# closed_at                                         2020-05-15 00:19:51+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      I can't get CNN / DailyMail dataset.\r\n\r\n``...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1940  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues/38
# id                                                                611677656
# node_id                                            MDU6SXNzdWU2MTE2Nzc2NTY=
# number                                                                   38
# title                                   [Checksums] Error for some datasets
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                  {'avatar_url': 'https://avatars.githubusercont...
# assignees                 [{'avatar_url': 'https://avatars.githubusercon...
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-05-04 08:00:16+00:00
# updated_at                                        2020-05-04 09:48:20+00:00
# closed_at                                         2020-05-04 09:48:20+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      The checksums command works very nicely for `s...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1941  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/6
# id                                                                600330836
# node_id                                            MDU6SXNzdWU2MDAzMzA4MzY=
# number                                                                    6
# title                     Error when citation is not given in the Datase...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-15 14:14:54+00:00
# updated_at                                        2020-04-29 09:23:22+00:00
# closed_at                                         2020-04-29 09:23:22+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      The following error is raised when the `citati...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1942  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/5
# id                                                                600295889
# node_id                                            MDU6SXNzdWU2MDAyOTU4ODk=
# number                                                                    5
# title                                      ValueError when a split is empty
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-15 13:25:13+00:00
# updated_at                                        2020-04-29 09:23:05+00:00
# closed_at                                         2020-04-29 09:23:05+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      When a split is empty either TEST, VALIDATION ...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1943  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/4
# id                                                                600185417
# node_id                                            MDU6SXNzdWU2MDAxODU0MTc=
# number                                                                    4
# title                     [Feature] Keep the list of labels of a dataset...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  6
# created_at                                        2020-04-15 10:17:10+00:00
# updated_at                                        2020-07-08 16:59:46+00:00
# closed_at                                         2020-05-04 06:11:57+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      It would be useful to keep the list of the lab...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1944  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/3
# id                                                                600180050
# node_id                                            MDU6SXNzdWU2MDAxODAwNTA=
# number                                                                    3
# title                                        [Feature] More dataset outputs
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-15 10:08:14+00:00
# updated_at                                        2020-05-04 06:12:27+00:00
# closed_at                                         2020-05-04 06:12:27+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      Add the following dataset outputs:\r\n\r\n- Sp...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1945
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/2
# id                                                                599767671
# node_id                                            MDU6SXNzdWU1OTk3Njc2NzE=
# number                                                                    2
# title                                         Issue to read a local dataset
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  5
# created_at                                        2020-04-14 18:18:51+00:00
# updated_at                                        2020-05-11 18:55:23+00:00
# closed_at                                         2020-05-11 18:55:22+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      Hello,\r\n\r\nAs proposed by @thomwolf, I open...
# reactions                 {'+1': 1, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
# [30 rows x 1946 columns]

# %%
(issues_dataset_closed_df['closed_at'] - issues_dataset_closed_df['created_at']).mean()
# Out:
# Timedelta('77 days 06:27:28.649023638')

# %%
(issues_dataset_closed_df['closed_at'] - issues_dataset_closed_df['created_at']).median()
# Out:
# Timedelta('5 days 17:36:28.500000')

# %%
(issues_dataset_closed_df['closed_at'] - issues_dataset_closed_df['created_at']).describe()
# Out:
# count                           1946
# mean      77 days 06:27:28.649023638
# std      175 days 16:54:51.213781774
# min                  0 days 00:00:18
# 25%           0 days 20:17:49.500000
# 50%           5 days 17:36:28.500000
# 75%                 34 days 16:36:16
# max               1081 days 08:05:48
# dtype: object

# %%
pull_request_dataset = issues_dataset.filter(lambda x: x["is_pull_request"] == True and x['state'] == 'closed')
# Out:
# Filter:   0%|          | 0/6279 [00:00<?, ? examples/s]

# %%
pull_request_dataset.set_format("pandas")
pull_request_df = pull_request_dataset[:]

# %%
pull_request_df.transpose().head(30)
# Out:
#                                                                        0     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6301
# id                                                               1940183999
# node_id                                                 PR_kwDODunzps5cpPVh
# number                                                                 6301
# title                                    Unpin `tensorflow` maximum version
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2023-10-12 14:58:07+00:00
# updated_at                                        2023-10-12 15:58:20+00:00
# closed_at                                         2023-10-12 15:49:54+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                         Removes the temporary pin introduced in #6264
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        1     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6300
# id                                                               1940153432
# node_id                                                 PR_kwDODunzps5cpIoG
# number                                                                 6300
# title                                           Unpin `jax` maximum version
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  6
# created_at                                        2023-10-12 14:42:40+00:00
# updated_at                                        2023-10-12 16:37:55+00:00
# closed_at                                         2023-10-12 16:28:57+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                                                 fix #6299\r\nfix #6202
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        2     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6298
# id                                                               1938797389
# node_id                                                 PR_kwDODunzps5ckg6j
# number                                                                 6298
# title                                               Doc readme improvements
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-11 21:51:12+00:00
# updated_at                                        2023-10-12 12:47:15+00:00
# closed_at                                         2023-10-12 12:38:19+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      Changes in the doc READMe:\r\n* adds two new s...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6297
# id                                                               1938752707
# node_id                                                 PR_kwDODunzps5ckXBa
# number                                                                 6297
# title                                                      Fix ArrayXD cast
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-11 21:14:59+00:00
# updated_at                                        2023-10-13 13:54:00+00:00
# closed_at                                         2023-10-13 13:45:30+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                                                             Fix #6291
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        4     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6295
# id                                                               1937362102
# node_id                                                 PR_kwDODunzps5cfiW8
# number                                                                 6295
# title                        Fix parquet columns argument in streaming mode
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2023-10-11 10:01:01+00:00
# updated_at                                        2023-10-11 16:30:24+00:00
# closed_at                                         2023-10-11 16:21:36+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      It was failing when there's a DatasetInfo with...
# reactions                 {'+1': 1, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        5     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6289
# id                                                               1935628506
# node_id                                                 PR_kwDODunzps5cZiay
# number                                                                 6289
# title                                                   testing doc-builder
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-10 15:17:29+00:00
# updated_at                                        2023-10-13 08:57:14+00:00
# closed_at                                         2023-10-13 08:56:48+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      testing https://github.com/huggingface/doc-bui...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        6     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6286
# id                                                               1932640128
# node_id                                                 PR_kwDODunzps5cPKNK
# number                                                                 6286
# title                                            Create DefunctDatasetError
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-09 09:23:23+00:00
# updated_at                                        2023-10-10 07:13:22+00:00
# closed_at                                         2023-10-10 07:03:04+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      Create `DefunctDatasetError` as a specific err...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        7     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6281
# id                                                               1928456959
# node_id                                                 PR_kwDODunzps5cBQPd
# number                                                                 6281
# title                       Improve documentation of dataset.from_generator
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-05 14:34:49+00:00
# updated_at                                        2023-10-05 19:09:07+00:00
# closed_at                                         2023-10-05 18:57:41+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      Improve documentation to clarify sharding beha...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        8     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6278
# id                                                               1927957877
# node_id                                                 PR_kwDODunzps5b_iKb
# number                                                                 6278
# title                                              No data files duplicates
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  4
# created_at                                        2023-10-05 10:31:58+00:00
# updated_at                                        2023-10-05 14:43:17+00:00
# closed_at                                         2023-10-05 14:43:17+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      I added a new DataFilesSet class to disallow d...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   1.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        9     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6265
# id                                                               1915651566
# node_id                                                 PR_kwDODunzps5bWDfc
# number                                                                 6265
# title                     Remove `apache_beam` import in `BeamBasedBuild...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  4
# created_at                                        2023-09-27 13:56:34+00:00
# updated_at                                        2023-09-28 18:34:02+00:00
# closed_at                                         2023-09-28 18:23:35+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      ... to avoid an `ImportError` raised in `BeamB...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                           ...  \
# url                       ...
# repository_url            ...
# labels_url                ...
# comments_url              ...
# events_url                ...
# html_url                  ...
# id                        ...
# node_id                   ...
# number                    ...
# title                     ...
# user                      ...
# labels                    ...
# state                     ...
# locked                    ...
# assignee                  ...
# assignees                 ...
# milestone                 ...
# comments                  ...
# created_at                ...
# updated_at                ...
# closed_at                 ...
# author_association        ...
# active_lock_reason        ...
# body                      ...
# reactions                 ...
# timeline_url              ...
# performed_via_github_app  ...
# state_reason              ...
# draft                     ...
# pull_request              ...
#
#                                                                        3696  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                    https://github.com/huggingface/datasets/pull/15
# id                                                                604906708
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA3NDEwOTk3
# number                                                                   15
# title                     [Tests] General Test Design for all dataset sc...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                 10
# created_at                                        2020-04-22 16:46:01+00:00
# updated_at                                        2022-10-04 09:31:54+00:00
# closed_at                                         2020-04-27 14:48:02+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      The general idea is similar to how testing is ...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3697  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                    https://github.com/huggingface/datasets/pull/14
# id                                                                604761315
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA3MjkzNjU5
# number                                                                   14
# title                       [Download] Only create dir if not already exist
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-22 13:32:51+00:00
# updated_at                                        2022-10-04 09:31:50+00:00
# closed_at                                         2020-04-23 08:27:33+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      This was quite annoying to find out :D. \r\nSo...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3698  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                    https://github.com/huggingface/datasets/pull/13
# id                                                                604547951
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA3MTIxMjkw
# number                                                                   13
# title                                                          [Make style]
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-22 08:10:06+00:00
# updated_at                                        2022-10-04 09:31:51+00:00
# closed_at                                         2020-04-23 13:02:22+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      Added Makefile and applied make style to all. ...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3699  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                    https://github.com/huggingface/datasets/pull/12
# id                                                                604518583
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA3MDk3MzA4
# number                                                                   12
# title                     [Map Function] add assert statement if map fun...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-22 07:21:24+00:00
# updated_at                                        2022-10-04 09:31:53+00:00
# closed_at                                         2020-04-24 06:29:03+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      IMO, if a function is provided that is not a p...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3700  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                    https://github.com/huggingface/datasets/pull/11
# id                                                                603921624
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA2NjExODk2
# number                                                                   11
# title                     [Convert TFDS to HFDS] Extend script to also a...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-21 11:25:33+00:00
# updated_at                                        2022-10-04 09:31:46+00:00
# closed_at                                         2020-04-21 20:47:00+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      Adds another argument to be able to convert on...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3701  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                    https://github.com/huggingface/datasets/pull/10
# id                                                                603909327
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA2NjAxNzQ2
# number                                                                   10
# title                     Name json file "squad.json" instead of "squad....
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-21 11:04:28+00:00
# updated_at                                        2022-10-04 09:31:44+00:00
# closed_at                                         2020-04-21 20:48:06+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3702  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/9
# id                                                                603894874
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA2NTkwMDQw
# number                                                                    9
# title                                                   [Clean up] Datasets
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2020-04-21 10:39:56+00:00
# updated_at                                        2022-10-04 09:31:42+00:00
# closed_at                                         2020-04-21 20:49:58+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      Clean up `nlp/datasets` folder. \r\n\r\nAs I u...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3703  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/8
# id                                                                601783243
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA0OTg0NDUz
# number                                                                    8
# title                     Fix issue 6: error when the citation is missin...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-17 08:04:26+00:00
# updated_at                                        2020-04-29 09:27:11+00:00
# closed_at                                         2020-04-20 13:24:12+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3704  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/7
# id                                                                601780534
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA0OTgyMzA2
# number                                                                    7
# title                                     Fix issue 5: allow empty datasets
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-17 07:59:56+00:00
# updated_at                                        2020-04-29 09:27:13+00:00
# closed_at                                         2020-04-20 13:23:48+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3705
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/1
# id                                                                599457467
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDAzMDk1NDYw
# number                                                                    1
# title                                        changing nlp.bool to nlp.bool_
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-14 10:18:02+00:00
# updated_at                                        2022-10-04 09:31:40+00:00
# closed_at                                         2020-04-14 12:01:40+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
# [30 rows x 3706 columns]

# %%
(pull_request_df['closed_at'] - pull_request_df['created_at']).describe()
# Out:
# count                          3706
# mean     15 days 03:06:04.498920669
# std      71 days 14:28:05.141772524
# min                 0 days 00:00:06
# 25%          0 days 03:16:48.500000
# 50%          1 days 04:23:30.500000
# 75%                 5 days 05:20:17
# max               984 days 16:05:16
# dtype: object

# %%
issue_number = 6301
url = f"https://api.github.com/repos/huggingface/datasets/issues/{issue_number}/comments"
response = requests.get(url, headers=headers)

# %%
response.json()
# Out:
# [{'url': 'https://api.github.com/repos/huggingface/datasets/issues/comments/1759794986',
#   'html_url': 'https://github.com/huggingface/datasets/pull/6301#issuecomment-1759794986',
#   'issue_url': 'https://api.github.com/repos/huggingface/datasets/issues/6301',
#   'id': 1759794986,
#   'node_id': 'IC_kwDODunzps5o5Fcq',
#   'user': {'login': 'github-actions[bot]',
#    'id': 41898282,
#    'node_id': 'MDM6Qm90NDE4OTgyODI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#    'html_url': 'https://github.com/apps/github-actions',
#    'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#    'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#    'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#    'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#    'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#    'type': 'Bot',
#    'site_admin': False},
#   'created_at': '2023-10-12T15:06:33Z',
#   'updated_at': '2023-10-12T15:06:33Z',
#   'author_association': 'NONE',
#   'body': '<details>\n<summary>Show benchmarks</summary>\n\nPyArrow==8.0.0\n\n<details>\n<summary>Show updated benchmarks!</summary>\n\n### Benchmark: benchmark_array_xd.json\n\n| metric | read_batch_formatted_as_numpy after write_array2d | read_batch_formatted_as_numpy after write_flattened_sequence | read_batch_formatted_as_numpy after write_nested_sequence | read_batch_unformated after write_array2d | read_batch_unformated after write_flattened_sequence | read_batch_unformated after write_nested_sequence | read_col_formatted_as_numpy after write_array2d | read_col_formatted_as_numpy after write_flattened_sequence | read_col_formatted_as_numpy after write_nested_sequence | read_col_unformated after write_array2d | read_col_unformated after write_flattened_sequence | read_col_unformated after write_nested_sequence | read_formatted_as_numpy after write_array2d | read_formatted_as_numpy after write_flattened_sequence | read_formatted_as_numpy after write_nested_sequence | read_unformated after write_array2d | read_unformated after write_flattened_sequence | read_unformated after write_nested_sequence | write_array2d | write_flattened_sequence | write_nested_sequence |\n|--------|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|\n| new / old (diff) | 0.006663 / 0.011353 (-0.004690) | 0.004091 / 0.011008 (-0.006918) | 0.084954 / 0.038508 (0.046445) | 0.071869 / 0.023109 (0.048760) | 0.314706 / 0.275898 (0.038808) | 0.352794 / 0.323480 (0.029314) | 0.004027 / 0.007986 (-0.003959) | 0.003371 / 0.004328 (-0.000957) | 0.065456 / 0.004250 (0.061205) | 0.055828 / 0.037052 (0.018775) | 0.316502 / 0.258489 (0.058013) | 0.377979 / 0.293841 (0.084138) | 0.030870 / 0.128546 (-0.097676) | 0.008616 / 0.075646 (-0.067030) | 0.288625 / 0.419271 (-0.130646) | 0.052314 / 0.043533 (0.008781) | 0.322725 / 0.255139 (0.067586) | 0.351810 / 0.283200 (0.068611) | 0.025726 / 0.141683 (-0.115957) | 1.439308 / 1.452155 (-0.012847) | 1.524484 / 1.492716 (0.031768) |\n\n### Benchmark: benchmark_getitem\\_100B.json\n\n| metric | get_batch_of\\_1024\\_random_rows | get_batch_of\\_1024\\_rows | get_first_row | get_last_row |\n|--------|---|---|---|---|\n| new / old (diff) | 0.235212 / 0.018006 (0.217206) | 0.444926 / 0.000490 (0.444437) | 0.009887 / 0.000200 (0.009687) | 0.000402 / 0.000054 (0.000347) |\n\n### Benchmark: benchmark_indices_mapping.json\n\n| metric | select | shard | shuffle | sort | train_test_split |\n|--------|---|---|---|---|---|\n| new / old (diff) | 0.028956 / 0.037411 (-0.008455) | 0.084401 / 0.014526 (0.069875) | 0.339686 / 0.176557 (0.163130) | 0.186785 / 0.737135 (-0.550350) | 0.195017 / 0.296338 (-0.101322) |\n\n### Benchmark: benchmark_iterating.json\n\n| metric | read 5000 | read 50000 | read_batch 50000 10 | read_batch 50000 100 | read_batch 50000 1000 | read_formatted numpy 5000 | read_formatted pandas 5000 | read_formatted tensorflow 5000 | read_formatted torch 5000 | read_formatted_batch numpy 5000 10 | read_formatted_batch numpy 5000 1000 | shuffled read 5000 | shuffled read 50000 | shuffled read_batch 50000 10 | shuffled read_batch 50000 100 | shuffled read_batch 50000 1000 | shuffled read_formatted numpy 5000 | shuffled read_formatted_batch numpy 5000 10 | shuffled read_formatted_batch numpy 5000 1000 |\n|--------|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|\n| new / old (diff) | 0.405480 / 0.215209 (0.190271) | 4.024315 / 2.077655 (1.946661) | 2.056398 / 1.504120 (0.552278) | 1.912099 / 1.541195 (0.370904) | 1.950119 / 1.468490 (0.481629) | 0.486071 / 4.584777 (-4.098706) | 3.578501 / 3.745712 (-0.167211) | 3.268980 / 5.269862 (-2.000881) | 2.018114 / 4.565676 (-2.547563) | 0.057440 / 0.424275 (-0.366835) | 0.007281 / 0.007607 (-0.000326) | 0.474760 / 0.226044 (0.248716) | 4.746908 / 2.268929 (2.477979) | 2.550111 / 55.444624 (-52.894513) | 2.171932 / 6.876477 (-4.704544) | 2.392235 / 2.142072 (0.250162) | 0.585940 / 4.805227 (-4.219287) | 0.136445 / 6.500664 ...
#   'reactions': {'url': 'https://api.github.com/repos/huggingface/datasets/issues/comments/1759794986/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/huggingface/datasets/issues/comments/1759889437',
#   'html_url': 'https://github.com/huggingface/datasets/pull/6301#issuecomment-1759889437',
#   'issue_url': 'https://api.github.com/repos/huggingface/datasets/issues/6301',
#   'id': 1759889437,
#   'node_id': 'IC_kwDODunzps5o5cgd',
#   'user': {'login': 'mariosasko',
#    'id': 47462742,
#    'node_id': 'MDQ6VXNlcjQ3NDYyNzQy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47462742?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mariosasko',
#    'html_url': 'https://github.com/mariosasko',
#    'followers_url': 'https://api.github.com/users/mariosasko/followers',
#    'following_url': 'https://api.github.com/users/mariosasko/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mariosasko/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mariosasko/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mariosasko/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mariosasko/orgs',
#    'repos_url': 'https://api.github.com/users/mariosasko/repos',
#    'events_url': 'https://api.github.com/users/mariosasko/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mariosasko/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'created_at': '2023-10-12T15:49:42Z',
#   'updated_at': '2023-10-12T15:49:42Z',
#   'author_association': 'CONTRIBUTOR',
#   'body': 'CI failures are unrelated',
#   'reactions': {'url': 'https://api.github.com/repos/huggingface/datasets/issues/comments/1759889437/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/huggingface/datasets/issues/comments/1759908734',
#   'html_url': 'https://github.com/huggingface/datasets/pull/6301#issuecomment-1759908734',
#   'issue_url': 'https://api.github.com/repos/huggingface/datasets/issues/6301',
#   'id': 1759908734,
#   'node_id': 'IC_kwDODunzps5o5hN-',
#   'user': {'login': 'github-actions[bot]',
#    'id': 41898282,
#    'node_id': 'MDM6Qm90NDE4OTgyODI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#    'html_url': 'https://github.com/apps/github-actions',
#    'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#    'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#    'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#    'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#    'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#    'type': 'Bot',
#    'site_admin': False},
#   'created_at': '2023-10-12T15:58:19Z',
#   'updated_at': '2023-10-12T15:58:19Z',
#   'author_association': 'NONE',
#   'body': '<details>\n<summary>Show benchmarks</summary>\n\nPyArrow==8.0.0\n\n<details>\n<summary>Show updated benchmarks!</summary>\n\n### Benchmark: benchmark_array_xd.json\n\n| metric | read_batch_formatted_as_numpy after write_array2d | read_batch_formatted_as_numpy after write_flattened_sequence | read_batch_formatted_as_numpy after write_nested_sequence | read_batch_unformated after write_array2d | read_batch_unformated after write_flattened_sequence | read_batch_unformated after write_nested_sequence | read_col_formatted_as_numpy after write_array2d | read_col_formatted_as_numpy after write_flattened_sequence | read_col_formatted_as_numpy after write_nested_sequence | read_col_unformated after write_array2d | read_col_unformated after write_flattened_sequence | read_col_unformated after write_nested_sequence | read_formatted_as_numpy after write_array2d | read_formatted_as_numpy after write_flattened_sequence | read_formatted_as_numpy after write_nested_sequence | read_unformated after write_array2d | read_unformated after write_flattened_sequence | read_unformated after write_nested_sequence | write_array2d | write_flattened_sequence | write_nested_sequence |\n|--------|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|\n| new / old (diff) | 0.005815 / 0.011353 (-0.005538) | 0.003419 / 0.011008 (-0.007589) | 0.080286 / 0.038508 (0.041778) | 0.056487 / 0.023109 (0.033377) | 0.304414 / 0.275898 (0.028516) | 0.341039 / 0.323480 (0.017559) | 0.004392 / 0.007986 (-0.003594) | 0.002852 / 0.004328 (-0.001477) | 0.062339 / 0.004250 (0.058089) | 0.044683 / 0.037052 (0.007630) | 0.311651 / 0.258489 (0.053162) | 0.357249 / 0.293841 (0.063409) | 0.027300 / 0.128546 (-0.101246) | 0.007963 / 0.075646 (-0.067683) | 0.261948 / 0.419271 (-0.157323) | 0.044952 / 0.043533 (0.001419) | 0.309990 / 0.255139 (0.054851) | 0.340735 / 0.283200 (0.057536) | 0.020786 / 0.141683 (-0.120897) | 1.471378 / 1.452155 (0.019224) | 1.517260 / 1.492716 (0.024543) |\n\n### Benchmark: benchmark_getitem\\_100B.json\n\n| metric | get_batch_of\\_1024\\_random_rows | get_batch_of\\_1024\\_rows | get_first_row | get_last_row |\n|--------|---|---|---|---|\n| new / old (diff) | 0.245447 / 0.018006 (0.227441) | 0.418967 / 0.000490 (0.418477) | 0.007039 / 0.000200 (0.006840) | 0.000196 / 0.000054 (0.000142) |\n\n### Benchmark: benchmark_indices_mapping.json\n\n| metric | select | shard | shuffle | sort | train_test_split |\n|--------|---|---|---|---|---|\n| new / old (diff) | 0.022880 / 0.037411 (-0.014532) | 0.071862 / 0.014526 (0.057337) | 0.083009 / 0.176557 (-0.093547) | 0.143414 / 0.737135 (-0.593722) | 0.082896 / 0.296338 (-0.213442) |\n\n### Benchmark: benchmark_iterating.json\n\n| metric | read 5000 | read 50000 | read_batch 50000 10 | read_batch 50000 100 | read_batch 50000 1000 | read_formatted numpy 5000 | read_formatted pandas 5000 | read_formatted tensorflow 5000 | read_formatted torch 5000 | read_formatted_batch numpy 5000 10 | read_formatted_batch numpy 5000 1000 | shuffled read 5000 | shuffled read 50000 | shuffled read_batch 50000 10 | shuffled read_batch 50000 100 | shuffled read_batch 50000 1000 | shuffled read_formatted numpy 5000 | shuffled read_formatted_batch numpy 5000 10 | shuffled read_formatted_batch numpy 5000 1000 |\n|--------|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|\n| new / old (diff) | 0.390645 / 0.215209 (0.175436) | 3.888104 / 2.077655 (1.810450) | 1.859572 / 1.504120 (0.355452) | 1.683803 / 1.541195 (0.142608) | 1.697902 / 1.468490 (0.229412) | 0.499537 / 4.584777 (-4.085239) | 3.015832 / 3.745712 (-0.729881) | 2.805696 / 5.269862 (-2.464166) | 1.830408 / 4.565676 (-2.735268) | 0.058191 / 0.424275 (-0.366085) | 0.006357 / 0.007607 (-0.001250) | 0.462486 / 0.226044 (0.236442) | 4.634951 / 2.268929 (2.366022) | 2.309364 / 55.444624 (-53.135260) | 1.979521 / 6.876477 (-4.896956) | 2.080011 / 2.142072 (-0.062062) | 0.593086 / 4.805227 (-4.212141) | 0.124856 / 6.50066 ...
#   'reactions': {'url': 'https://api.github.com/repos/huggingface/datasets/issues/comments/1759908734/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None}]

# %%
import requests
from retrying import retry

# %%
@retry(
    stop_max_attempt_number=5,  # Number of max retries
    wait_fixed=36_00_000  # Wait for 1 hour between each retry
)
def get_comments(issue_number):
    url = f"https://api.github.com/repos/huggingface/datasets/issues/{issue_number}/comments"
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return [r['body'] for r in response.json()]

# %%
get_comments(2792)
# Out:
# ["@albertvillanova my tests are failing here:\r\n```\r\ndataset_name = 'gooaq'\r\n\r\n    def test_load_dataset(self, dataset_name):\r\n        configs = self.dataset_tester.load_all_configs(dataset_name, is_local=True)[:1]\r\n>       self.dataset_tester.check_load_dataset(dataset_name, configs, is_local=True, use_local_dummy_data=True)\r\n\r\ntests/test_dataset_common.py:234: \r\n_ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ \r\ntests/test_dataset_common.py:187: in check_load_dataset\r\n    self.parent.assertTrue(len(dataset[split]) > 0)\r\nE   AssertionError: False is not true\r\n```\r\nWhen I try loading dataset on local machine it works fine. Any suggestions on how can I avoid this error?",
#  'Thanks for the help, @albertvillanova! All tests are passing now.']

# %%
if not Path('data-issues-comments.csv').exists():
    issues_with_comments_dataset = issues_dataset.map(lambda x: {"comments": get_comments(x["number"])})
    issues_with_comments_dataset.to_csv('data-issues-comments.csv')

# %%
issues_with_comments_dataset = load_dataset("csv", data_files = "data-issues-comments.csv", split="train")

# %%
issues_with_comments_dataset
# Out:
# Dataset({
#     features: ['url', 'repository_url', 'labels_url', 'comments_url', 'events_url', 'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels', 'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments', 'created_at', 'updated_at', 'closed_at', 'author_association', 'active_lock_reason', 'body', 'reactions', 'timeline_url', 'performed_via_github_app', 'state_reason', 'draft', 'pull_request', 'is_pull_request'],
#     num_rows: 6279
# })

# %%
len(issues_with_comments_dataset)
# Out:
# 6279

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
issues_with_comments_dataset.push_to_hub("github-issues")
# Out:
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/7 [00:00<?, ?ba/s]
# Downloading metadata:   0%|          | 0.00/400 [00:00<?, ?B/s]
# Repo card metadata block was not found. Setting CardData to empty.

# %% [markdown]
# ## Nbdev github issues

# %%
if not Path("./nbdev-issues.jsonl").exists(): 
    nbdev_issues_dataset = fetch_issues('fastai', 'nbdev')

# %%
df = pd.read_json("./nbdev-issues.jsonl", orient="records", lines=True)

# %%
df.transpose().head(30)
# Out:
#                                                                        0     \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                          https://github.com/fastai/nbdev/pull/1374
# id                                                               1953415859
# node_id                                                 PR_kwDODUMwOs5dVgfQ
# number                                                                 1374
# title                                                           fixes #1364
# user                      {'login': 'deven367', 'id': 31466137, 'node_id...
# labels                                                                   []
# state                                                                  open
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-20 02:59:01+00:00
# updated_at                                        2023-10-20 03:02:06+00:00
# closed_at                                                               NaT
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/fastai/n...
# body                      Adding a minor docstring for `nbdev_readme`, @...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                           None
#
#                                                                        1     \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                          https://github.com/fastai/nbdev/pull/1373
# id                                                               1951064047
# node_id                                                 PR_kwDODUMwOs5dNiY8
# number                                                                 1373
# title                                                 add support for 3.11
# user                      {'login': 'deven367', 'id': 31466137, 'node_id...
# labels                    [{'id': 1683921099, 'node_id': 'MDU6TGFiZWwxNj...
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  7
# created_at                                        2023-10-19 02:22:38+00:00
# updated_at                                        2023-10-19 04:36:36+00:00
# closed_at                                         2023-10-19 04:14:24+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/fastai/n...
# body                      hello, I'm trying to add support for py3.11 fo...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                           None
#
#                                                                        2     \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                        https://github.com/fastai/nbdev/issues/1372
# id                                                               1950586692
# node_id                                                  I_kwDODUMwOs50Q5dE
# number                                                                 1372
# title                     In settings.ini `min_python = 3.11` causes pro...
# user                      {'login': 'Martin15135215', 'id': 110968398, '...
# labels                    [{'id': 1683921090, 'node_id': 'MDU6TGFiZWwxNj...
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-18 20:24:19+00:00
# updated_at                                        2023-10-19 06:32:57+00:00
# closed_at                                         2023-10-19 04:14:25+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   NaN
# pull_request                                                           None
# body                      Traceback:\r\n\r\n```\r\npip install -e '.[dev...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
#
#                                                                        3     \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                        https://github.com/fastai/nbdev/issues/1371
# id                                                               1945085395
# node_id                                                  I_kwDODUMwOs5z76XT
# number                                                                 1371
# title                     [Question] Can I install nbdev in a virtual en...
# user                      {'login': 'Martin15135215', 'id': 110968398, '...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2023-10-16 12:20:19+00:00
# updated_at                                        2023-10-19 19:45:14+00:00
# closed_at                                         2023-10-19 19:45:13+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   NaN
# pull_request                                                           None
# body                      https://github.com/fastai/nbdev/blob/4af4d479c...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
#
#                                                                        4     \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                        https://github.com/fastai/nbdev/issues/1370
# id                                                               1924456725
# node_id                                                  I_kwDODUMwOs5ytOEV
# number                                                                 1370
# title                     nbdev_test having issues because of Python cac...
# user                      {'login': 'loayshaqir1', 'id': 118802302, 'nod...
# labels                    [{'id': 1683921090, 'node_id': 'MDU6TGFiZWwxNj...
# state                                                                  open
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-10-03 15:59:53+00:00
# updated_at                                        2023-10-03 15:59:53+00:00
# closed_at                                                               NaT
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   NaN
# pull_request                                                           None
# body                      No need to add example as the explanation of t...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                           None
#
#                                                                        5     \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                        https://github.com/fastai/nbdev/issues/1369
# id                                                               1906570101
# node_id                                                  I_kwDODUMwOs5xo_N1
# number                                                                 1369
# title                     keyword only '*' does not work with documentation
# user                      {'login': 'CyprienRicque', 'id': 48893621, 'no...
# labels                    [{'id': 1683921090, 'node_id': 'MDU6TGFiZWwxNj...
# state                                                                  open
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-09-21 09:50:06+00:00
# updated_at                                        2023-09-21 09:52:34+00:00
# closed_at                                                               NaT
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   NaN
# pull_request                                                           None
# body                      # Example\r\n\r\nHello! Using keyword only arg...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                           None
#
#                                                                        6     \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                        https://github.com/fastai/nbdev/issues/1368
# id                                                               1898478453
# node_id                                                  I_kwDODUMwOs5xKHt1
# number                                                                 1368
# title                     `nbdev_test` fails to run tests when preceded ...
# user                      {'login': 'amaiya', 'id': 47191980, 'node_id':...
# labels                    [{'id': 1683921090, 'node_id': 'MDU6TGFiZWwxNj...
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-09-15 13:52:06+00:00
# updated_at                                        2023-09-16 14:43:18+00:00
# closed_at                                         2023-09-15 14:06:12+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   NaN
# pull_request                                                           None
# body                      Importing and instantiating `langchain.embeddi...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
#
#                                                                        7     \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                        https://github.com/fastai/nbdev/issues/1367
# id                                                               1896648057
# node_id                                                  I_kwDODUMwOs5xDI15
# number                                                                 1367
# title                            How to document a module and or constants?
# user                      {'login': 'dsm-72', 'id': 100158155, 'node_id'...
# labels                                                                   []
# state                                                                  open
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-09-14 14:02:39+00:00
# updated_at                                        2023-09-16 21:07:26+00:00
# closed_at                                                               NaT
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   NaN
# pull_request                                                           None
# body                      Let's say I have a notebook `00_cons.ipynb` Wh...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                           None
#
#                                                                        8     \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                        https://github.com/fastai/nbdev/issues/1366
# id                                                               1887710163
# node_id                                                  I_kwDODUMwOs5whCvT
# number                                                                 1366
# title                     `black` is not found when `nbdev_export` is ru...
# user                      {'login': 'ulupo', 'id': 46537483, 'node_id': ...
# labels                    [{'id': 1683921090, 'node_id': 'MDU6TGFiZWwxNj...
# state                                                                  open
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-09-08 13:37:11+00:00
# updated_at                                        2023-09-08 13:44:49+00:00
# closed_at                                                               NaT
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   NaN
# pull_request                                                           None
# body                      When creating a brand new repository and setti...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                           None
#
#                                                                        9     \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                        https://github.com/fastai/nbdev/issues/1365
# id                                                               1877574729
# node_id                                                  I_kwDODUMwOs5v6YRJ
# number                                                                 1365
# title                     nbdev_prepare and nbdev_test hang if I use the...
# user                      {'login': 'Taytay', 'id': 1330693, 'node_id': ...
# labels                    [{'id': 1683921090, 'node_id': 'MDU6TGFiZWwxNj...
# state                                                                  open
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-09-01 14:52:41+00:00
# updated_at                                        2023-09-01 15:01:14+00:00
# closed_at                                                               NaT
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   NaN
# pull_request                                                           None
# body                      (First, thanks for nbdev. This project is grea...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                           None
#
#                           ...  \
# url                       ...
# repository_url            ...
# labels_url                ...
# comments_url              ...
# events_url                ...
# html_url                  ...
# id                        ...
# node_id                   ...
# number                    ...
# title                     ...
# user                      ...
# labels                    ...
# state                     ...
# locked                    ...
# assignee                  ...
# assignees                 ...
# milestone                 ...
# comments                  ...
# created_at                ...
# updated_at                ...
# closed_at                 ...
# author_association        ...
# active_lock_reason        ...
# draft                     ...
# pull_request              ...
# body                      ...
# reactions                 ...
# timeline_url              ...
# performed_via_github_app  ...
# state_reason              ...
#
#                                                                        1456  \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                          https://github.com/fastai/nbdev/issues/10
# id                                                                531889946
# node_id                                            MDU6SXNzdWU1MzE4ODk5NDY=
# number                                                                   10
# title                                          Link to generate repo broken
# user                      {'login': 'zacharyneveu', 'id': 23347363, 'nod...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2019-12-03 10:41:18+00:00
# updated_at                                        2019-12-03 14:38:56+00:00
# closed_at                                         2019-12-03 14:38:56+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   NaN
# pull_request                                                           None
# body                      Link to `https://github.com/fastai/nbdev_templ...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
#
#                                                                        1457  \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                           https://github.com/fastai/nbdev/issues/9
# id                                                                531358476
# node_id                                            MDU6SXNzdWU1MzEzNTg0NzY=
# number                                                                    9
# title                                 Link to a template in Getting Started
# user                      {'login': '8bitmp3', 'id': 19637339, 'node_id'...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2019-12-02 17:51:59+00:00
# updated_at                                        2019-12-08 03:35:23+00:00
# closed_at                                         2019-12-02 17:59:15+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   NaN
# pull_request                                                           None
# body                      Hey @sgugger @jph00—awesome job on `nbdev`. Ju...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
#
#                                                                        1458  \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                           https://github.com/fastai/nbdev/issues/8
# id                                                                531082067
# node_id                                            MDU6SXNzdWU1MzEwODIwNjc=
# number                                                                    8
# title                                                     Docs not building
# user                      {'login': 'stuartmarsden', 'id': 8310690, 'nod...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  5
# created_at                                        2019-12-02 11:59:33+00:00
# updated_at                                        2019-12-03 05:03:23+00:00
# closed_at                                         2019-12-02 14:32:28+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   NaN
# pull_request                                                           None
# body                      I just made a test repo and followed the getti...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
#
#                                                                        1459  \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                             https://github.com/fastai/nbdev/pull/7
# id                                                                530500488
# node_id                                    MDExOlB1bGxSZXF1ZXN0MzQ3MTY5MDgz
# number                                                                    7
# title                                                                 Tools
# user                      {'login': 'holyfiddlex', 'id': 24305020, 'node...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2019-11-29 22:28:36+00:00
# updated_at                                        2019-11-29 22:39:32+00:00
# closed_at                                         2019-11-29 22:39:32+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   1.0
# pull_request              {'url': 'https://api.github.com/repos/fastai/n...
# body                      Tools for notebook development, Mostly taken f...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                           None
#
#                                                                        1460  \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                             https://github.com/fastai/nbdev/pull/6
# id                                                                530496253
# node_id                                    MDExOlB1bGxSZXF1ZXN0MzQ3MTY1Nzcx
# number                                                                    6
# title                                                          Docker build
# user                      {'login': 'hamelsmu', 'id': 1483922, 'node_id'...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  4
# created_at                                        2019-11-29 22:00:36+00:00
# updated_at                                        2020-01-10 14:41:12+00:00
# closed_at                                         2019-11-29 22:09:25+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/fastai/n...
# body                      cc: @jph00 following up from our conversation ...
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                           None
#
#                                                                        1461  \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                             https://github.com/fastai/nbdev/pull/5
# id                                                                530493499
# node_id                                    MDExOlB1bGxSZXF1ZXN0MzQ3MTYzODU2
# number                                                                    5
# title                                                                 Tools
# user                      {'login': 'holyfiddlex', 'id': 24305020, 'node...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2019-11-29 21:43:42+00:00
# updated_at                                        2019-11-29 21:45:21+00:00
# closed_at                                         2019-11-29 21:45:21+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/fastai/n...
# body
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                           None
#
#                                                                        1462  \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                             https://github.com/fastai/nbdev/pull/4
# id                                                                530490036
# node_id                                    MDExOlB1bGxSZXF1ZXN0MzQ3MTYxMjIy
# number                                                                    4
# title                                                      added dockerfile
# user                      {'login': 'hamelsmu', 'id': 1483922, 'node_id'...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2019-11-29 21:22:14+00:00
# updated_at                                        2019-11-29 21:24:04+00:00
# closed_at                                         2019-11-29 21:22:30+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/fastai/n...
# body
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                           None
#
#                                                                        1463  \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                             https://github.com/fastai/nbdev/pull/3
# id                                                                530150863
# node_id                                    MDExOlB1bGxSZXF1ZXN0MzQ2ODkwNDgy
# number                                                                    3
# title                                                        Update LICENSE
# user                      {'login': 'hamelsmu', 'id': 1483922, 'node_id'...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2019-11-29 04:31:45+00:00
# updated_at                                        2019-11-29 13:48:45+00:00
# closed_at                                         2019-11-29 13:48:42+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/fastai/n...
# body                                                     Add Copyright info
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                           None
#
#                                                                        1464  \
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                             https://github.com/fastai/nbdev/pull/2
# id                                                                528462404
# node_id                                    MDExOlB1bGxSZXF1ZXN0MzQ1NTE5Mzk2
# number                                                                    2
# title                                                          typos README
# user                      {'login': 'holyfiddlex', 'id': 24305020, 'node...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2019-11-26 03:22:08+00:00
# updated_at                                        2019-11-26 14:46:59+00:00
# closed_at                                         2019-11-26 14:46:59+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/fastai/n...
# body                                                Small readme typo fixes
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                           None
#
#                                                                        1465
# url                       https://api.github.com/repos/fastai/nbdev/issu...
# repository_url                    https://api.github.com/repos/fastai/nbdev
# labels_url                https://api.github.com/repos/fastai/nbdev/issu...
# comments_url              https://api.github.com/repos/fastai/nbdev/issu...
# events_url                https://api.github.com/repos/fastai/nbdev/issu...
# html_url                             https://github.com/fastai/nbdev/pull/1
# id                                                                528258363
# node_id                                    MDExOlB1bGxSZXF1ZXN0MzQ1MzU0ODU4
# number                                                                    1
# title                                                              fix typo
# user                      {'login': 'radekosmulski', 'id': 2444926, 'nod...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2019-11-25 18:24:42+00:00
# updated_at                                        2019-11-26 14:46:24+00:00
# closed_at                                         2019-11-26 14:46:23+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/fastai/n...
# body
# reactions                 {'url': 'https://api.github.com/repos/fastai/n...
# timeline_url              https://api.github.com/repos/fastai/nbdev/issu...
# performed_via_github_app                                                NaN
# state_reason                                                           None
#
# [30 rows x 1466 columns]

# %%
from datasets import Dataset
nbdev_issues_dataset = Dataset.from_pandas(df)
nbdev_issues_dataset
# Out:
# Dataset({
#     features: ['url', 'repository_url', 'labels_url', 'comments_url', 'events_url', 'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels', 'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments', 'created_at', 'updated_at', 'closed_at', 'author_association', 'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions', 'timeline_url', 'performed_via_github_app', 'state_reason'],
#     num_rows: 1466
# })

# %%
nbdev_issues_dataset
# Out:
# [[],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': '0075ca',
#    'default': True,
#    'description': 'Improvements or additions to documentation',
#    'id': 1683921093,
#    'name': 'documentation',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkz',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/documentation'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': '0075ca',
#    'default': True,
#    'description': 'Improvements or additions to documentation',
#    'id': 1683921093,
#    'name': 'documentation',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkz',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/documentation'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': '0075ca',
#    'default': True,
#    'description': 'Improvements or additions to documentation',
#    'id': 1683921093,
#    'name': 'documentation',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkz',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/documentation'}],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': '0075ca',
#    'default': True,
#    'description': 'Improvements or additions to documentation',
#    'id': 1683921093,
#    'name': 'documentation',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkz',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/documentation'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': '398C44',
#    'default': False,
#    'description': '',
#    'id': 2606415055,
#    'name': 'waiting for response',
#    'node_id': 'MDU6TGFiZWwyNjA2NDE1MDU1',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/waiting%20for%20response'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'},
#   {'color': 'd876e3',
#    'default': True,
#    'description': 'Further information is requested',
#    'id': 1683921111,
#    'name': 'question',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMTEx',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/question'}],
#  [{'color': '0075ca',
#    'default': True,
#    'description': 'Improvements or additions to documentation',
#    'id': 1683921093,
#    'name': 'documentation',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkz',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/documentation'},
#   {'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': '0075ca',
#    'default': True,
#    'description': 'Improvements or additions to documentation',
#    'id': 1683921093,
#    'name': 'documentation',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkz',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/documentation'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': '398C44',
#    'default': False,
#    'description': '',
#    'id': 2606415055,
#    'name': 'waiting for response',
#    'node_id': 'MDU6TGFiZWwyNjA2NDE1MDU1',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/waiting%20for%20response'},
#   {'color': '723D4B',
#    'default': False,
#    'description': 'minimal reproduction of issue has not been provided',
#    'id': 4610489744,
#    'name': 'needs-minimal-repro',
#    'node_id': 'LA_kwDODUMwOs8AAAABEs59kA',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/needs-minimal-repro'}],
#  [],
#  [{'color': '398C44',
#    'default': False,
#    'description': '',
#    'id': 2606415055,
#    'name': 'waiting for response',
#    'node_id': 'MDU6TGFiZWwyNjA2NDE1MDU1',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/waiting%20for%20response'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': '723D4B',
#    'default': False,
#    'description': 'minimal reproduction of issue has not been provided',
#    'id': 4610489744,
#    'name': 'needs-minimal-repro',
#    'node_id': 'LA_kwDODUMwOs8AAAABEs59kA',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/needs-minimal-repro'}],
#  [{'color': '723D4B',
#    'default': False,
#    'description': 'minimal reproduction of issue has not been provided',
#    'id': 4610489744,
#    'name': 'needs-minimal-repro',
#    'node_id': 'LA_kwDODUMwOs8AAAABEs59kA',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/needs-minimal-repro'}],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': 'D92121',
#    'default': False,
#    'description': '',
#    'id': 2348151933,
#    'name': 'breaking',
#    'node_id': 'MDU6TGFiZWwyMzQ4MTUxOTMz',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/breaking'}],
#  [{'color': '0075ca',
#    'default': True,
#    'description': 'Improvements or additions to documentation',
#    'id': 1683921093,
#    'name': 'documentation',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkz',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/documentation'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [{'color': '398C44',
#    'default': False,
#    'description': '',
#    'id': 2606415055,
#    'name': 'waiting for response',
#    'node_id': 'MDU6TGFiZWwyNjA2NDE1MDU1',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/waiting%20for%20response'}],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': '398C44',
#    'default': False,
#    'description': '',
#    'id': 2606415055,
#    'name': 'waiting for response',
#    'node_id': 'MDU6TGFiZWwyNjA2NDE1MDU1',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/waiting%20for%20response'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': '398C44',
#    'default': False,
#    'description': '',
#    'id': 2606415055,
#    'name': 'waiting for response',
#    'node_id': 'MDU6TGFiZWwyNjA2NDE1MDU1',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/waiting%20for%20response'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': '398C44',
#    'default': False,
#    'description': '',
#    'id': 2606415055,
#    'name': 'waiting for response',
#    'node_id': 'MDU6TGFiZWwyNjA2NDE1MDU1',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/waiting%20for%20response'}],
#  [{'color': '398C44',
#    'default': False,
#    'description': '',
#    'id': 2606415055,
#    'name': 'waiting for response',
#    'node_id': 'MDU6TGFiZWwyNjA2NDE1MDU1',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/waiting%20for%20response'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': '398C44',
#    'default': False,
#    'description': '',
#    'id': 2606415055,
#    'name': 'waiting for response',
#    'node_id': 'MDU6TGFiZWwyNjA2NDE1MDU1',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/waiting%20for%20response'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': '0075ca',
#    'default': True,
#    'description': 'Improvements or additions to documentation',
#    'id': 1683921093,
#    'name': 'documentation',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkz',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/documentation'}],
#  [{'color': '723D4B',
#    'default': False,
#    'description': 'minimal reproduction of issue has not been provided',
#    'id': 4610489744,
#    'name': 'needs-minimal-repro',
#    'node_id': 'LA_kwDODUMwOs8AAAABEs59kA',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/needs-minimal-repro'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': '398C44',
#    'default': False,
#    'description': '',
#    'id': 2606415055,
#    'name': 'waiting for response',
#    'node_id': 'MDU6TGFiZWwyNjA2NDE1MDU1',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/waiting%20for%20response'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'},
#   {'color': 'd876e3',
#    'default': True,
#    'description': 'Further information is requested',
#    'id': 1683921111,
#    'name': 'question',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMTEx',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/question'}],
#  [{'color': '0075ca',
#    'default': True,
#    'description': 'Improvements or additions to documentation',
#    'id': 1683921093,
#    'name': 'documentation',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkz',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/documentation'},
#   {'color': '7057ff',
# ...
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'D93F0B',
#    'default': False,
#    'description': '',
#    'id': 4362640076,
#    'name': 'priority',
#    'node_id': 'LA_kwDODUMwOs8AAAABBAiazA',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/priority'}],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [{'color': 'D93F0B',
#    'default': False,
#    'description': '',
#    'id': 4362640076,
#    'name': 'priority',
#    'node_id': 'LA_kwDODUMwOs8AAAABBAiazA',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/priority'}],
#  [{'color': 'D93F0B',
#    'default': False,
#    'description': '',
#    'id': 4362640076,
#    'name': 'priority',
#    'node_id': 'LA_kwDODUMwOs8AAAABBAiazA',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/priority'}],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'd876e3',
#    'default': True,
#    'description': 'Further information is requested',
#    'id': 1683921111,
#    'name': 'question',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMTEx',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/question'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'},
#   {'color': '0075ca',
#    'default': True,
#    'description': 'Improvements or additions to documentation',
#    'id': 1683921093,
#    'name': 'documentation',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkz',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/documentation'}],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'},
#   {'color': '7057ff',
#    'default': True,
#    'description': 'Good for newcomers',
#    'id': 1683921102,
#    'name': 'good first issue',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMTAy',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/good%20first%20issue'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'},
#   {'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [{'color': '0366d6',
#    'default': False,
#    'description': 'Pull requests that update a dependency file',
#    'id': 3016155158,
#    'name': 'dependencies',
#    'node_id': 'MDU6TGFiZWwzMDE2MTU1MTU4',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/dependencies'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': '0366d6',
#    'default': False,
#    'description': 'Pull requests that update a dependency file',
#    'id': 3016155158,
#    'name': 'dependencies',
#    'node_id': 'MDU6TGFiZWwzMDE2MTU1MTU4',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/dependencies'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [],
#  [],
#  [{'color': '0366d6',
#    'default': False,
#    'description': 'Pull requests that update a dependency file',
#    'id': 3016155158,
#    'name': 'dependencies',
#    'node_id': 'MDU6TGFiZWwzMDE2MTU1MTU4',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/dependencies'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': '0366d6',
#    'default': False,
#    'description': 'Pull requests that update a dependency file',
#    'id': 3016155158,
#    'name': 'dependencies',
#    'node_id': 'MDU6TGFiZWwzMDE2MTU1MTU4',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/dependencies'}],
#  [],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'color': 'a2eeef',
#    'default': True,
#    'description': 'New feature or request',
#    'id': 1683921099,
#    'name': 'enhancement',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDk5',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/enhancement'}],
#  [],
#  [],
#  [{'color': 'FBCA04',
#    'default': True,
#    'description': "Something isn't working",
#    'id': 1683921090,
#    'name': 'bug',
#    'node_id': 'MDU6TGFiZWwxNjgzOTIxMDkw',
#    'url': 'https://api.github.com/repos/fastai/nbdev/labels/bug'}],
#  ...]
