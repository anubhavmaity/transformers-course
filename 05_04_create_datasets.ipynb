# %% [markdown]
# # Datasets to the rescue!

# %%
# !pip install requests
# !pip install python-dotenv

# %%
import requests
from dotenv import dotenv_values
import time
import math
from pathlib import Path
import pandas as pd
from tqdm.notebook import tqdm
from datasets import load_dataset

# %%
url = "https://api.github.com/repos/huggingface/datasets/issues?page=1&per_page=1"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'url': 'https://api.github.com/repos/huggingface/datasets/issues/6310',
#   'repository_url': 'https://api.github.com/repos/huggingface/datasets',
#   'labels_url': 'https://api.github.com/repos/huggingface/datasets/issues/6310/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/huggingface/datasets/issues/6310/comments',
#   'events_url': 'https://api.github.com/repos/huggingface/datasets/issues/6310/events',
#   'html_url': 'https://github.com/huggingface/datasets/pull/6310',
#   'id': 1947457988,
#   'node_id': 'PR_kwDODunzps5dBPnY',
#   'number': 6310,
#   'title': 'Add return_file_name in load_dataset',
#   'user': {'login': 'juliendenize',
#    'id': 40604584,
#    'node_id': 'MDQ6VXNlcjQwNjA0NTg0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40604584?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/juliendenize',
#    'html_url': 'https://github.com/juliendenize',
#    'followers_url': 'https://api.github.com/users/juliendenize/followers',
#    'following_url': 'https://api.github.com/users/juliendenize/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/juliendenize/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/juliendenize/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/juliendenize/subscriptions',
#    'organizations_url': 'https://api.github.com/users/juliendenize/orgs',
#    'repos_url': 'https://api.github.com/users/juliendenize/repos',
#    'events_url': 'https://api.github.com/users/juliendenize/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/juliendenize/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-10-17T13:36:57Z',
#   'updated_at': '2023-10-17T13:36:57Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/huggingface/datasets/pulls/6310',
#    'html_url': 'https://github.com/huggingface/datasets/pull/6310',
#    'diff_url': 'https://github.com/huggingface/datasets/pull/6310.diff',
#    'patch_url': 'https://github.com/huggingface/datasets/pull/6310.patch',
#    'merged_at': None},
#   'body': 'Proposition to solve #5806.\r\n\r\nAdded an optional parameter `return_file_name` in the dataset builder config. When set to `True`, the function will include the file name corresponding to the sample in the returned output.\r\n\r\nThere is a difference between arrow-based and folder-based datasets\r\n- for arrow-based: a column is concatenated after the table is cast.\r\n- for folder-based: `dataset.info.features` has the entry `file_name` and the original file name is passed to the `sample_metadata` dictionary. \r\n\r\nThe difference in behavior might be a concern, also I do not know whether the `file_name` should return the original file path or the downloaded one for folder-based datasets.\r\n\r\nI added some tests for the datasets that already had a test file.',
#   'reactions': {'url': 'https://api.github.com/repos/huggingface/datasets/issues/6310/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/huggingface/datasets/issues/6310/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
config = dotenv_values(".env")

# %%
headers = {"Authorization": f"token {config['GITHUB_TOKEN']}"}

# %%
def fetch_issues(
    owner="huggingface",
    repo="datasets",
    num_issues=10_000,
    rate_limit=5_000,
    issues_path=Path('.'),
):
    
    if not issues_path.is_dir():
        issues_path.mkdir(exist_ok=True)

    batch = []
    all_issues = []
    per_page = 100 # Number of issues to return per page
    num_pages = math.ceil(num_issues / per_page)
    base_url = "https://api.github.com/repos"

    for page in tqdm(range(num_pages)):
        query = f"issues?page={page}&per_page={per_page}&state=all"
        issues = requests.get(f"{base_url}/{owner}/{repo}/{query}", headers=headers)
        batch.extend(issues.json())

        if len(batch) > rate_limit and len(all_issues) < num_issues:
            all_issues.extend(batch)
            batch = []
            print(f"Reached Github rate limit. Sleeping for one hour ...")
            time.sleep(60 * 60 + 1)

    all_issues.extend(batch)
    df = pd.DataFrame.from_records(all_issues)
    df.to_json(f"{issues_path}/{repo}-issues.jsonl", orient="records", lines=True)
    print(f"Downloaded all the issues for {repo}! Dataset stored at {issues_path}/{repo}-issues.jsonl")

# %%
Path("./datasets-issues.jsonl").exists()
# Out:
# True

# %%
if not Path("./datasets-issues.jsonl").exists(): fetch_issues()

# %%
df = pd.read_json("./datasets-issues.jsonl", orient="records", lines=True)

# %%
df.transpose().head(30)
# Out:
#                                                                        0     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1943466532
# node_id                                                  I_kwDODunzps5z1vIk
# number                                                                 6303
# title                              Parquet uploads off-by-one naming scheme
# user                      {'login': 'ZachNagengast', 'id': 1981179, 'nod...
# labels                                                                   []
# state                                                                  open
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-10-14 18:31:03+00:00
# updated_at                                        2023-10-14 18:31:03+00:00
# closed_at                                                               NaT
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\n\nI noticed this numberi...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1942096078
# node_id                                                  I_kwDODunzps5zwgjO
# number                                                                 6302
# title                     ArrowWriter/ParquetWriter `write` method does ...
# user                      {'login': 'Rassibassi', 'id': 2855550, 'node_i...
# labels                                                                   []
# state                                                                  open
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-10-13 14:43:36+00:00
# updated_at                                        2023-10-13 14:43:36+00:00
# closed_at                                                               NaT
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\n\nAn example from [1], d...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        2     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6301
# id                                                               1940183999
# node_id                                                 PR_kwDODunzps5cpPVh
# number                                                                 6301
# title                                    Unpin `tensorflow` maximum version
# user                      {'login': 'mariosasko', 'id': 47462742, 'node_...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2023-10-12 14:58:07+00:00
# updated_at                                        2023-10-12 15:58:20+00:00
# closed_at                                         2023-10-12 15:49:54+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                         Removes the temporary pin introduced in #6264
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        3     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6300
# id                                                               1940153432
# node_id                                                 PR_kwDODunzps5cpIoG
# number                                                                 6300
# title                                           Unpin `jax` maximum version
# user                      {'login': 'mariosasko', 'id': 47462742, 'node_...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  6
# created_at                                        2023-10-12 14:42:40+00:00
# updated_at                                        2023-10-12 16:37:55+00:00
# closed_at                                         2023-10-12 16:28:57+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                                                 fix #6299\r\nfix #6202
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        4     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1939649238
# node_id                                                  I_kwDODunzps5znLLW
# number                                                                 6299
# title                                     Support for newer versions of JAX
# user                      {'login': 'ddrous', 'id': 25456859, 'node_id':...
# labels                    [{'id': 1935892871, 'node_id': 'MDU6TGFiZWwxOT...
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-10-12 10:03:46+00:00
# updated_at                                        2023-10-12 16:28:59+00:00
# closed_at                                         2023-10-12 16:28:59+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Feature request\r\n\r\nHi,\r\n\r\nI like y...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        5     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6298
# id                                                               1938797389
# node_id                                                 PR_kwDODunzps5ckg6j
# number                                                                 6298
# title                                               Doc readme improvements
# user                      {'login': 'mariosasko', 'id': 47462742, 'node_...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-11 21:51:12+00:00
# updated_at                                        2023-10-12 12:47:15+00:00
# closed_at                                         2023-10-12 12:38:19+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      Changes in the doc READMe:\r\n* adds two new s...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        6     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6297
# id                                                               1938752707
# node_id                                                 PR_kwDODunzps5ckXBa
# number                                                                 6297
# title                                                      Fix ArrayXD cast
# user                      {'login': 'mariosasko', 'id': 47462742, 'node_...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-11 21:14:59+00:00
# updated_at                                        2023-10-13 13:54:00+00:00
# closed_at                                         2023-10-13 13:45:30+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                                                             Fix #6291
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        7     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6296
# id                                                               1938453845
# node_id                                                 PR_kwDODunzps5cjUs1
# number                                                                 6296
# title                         Move `exceptions.py` to `utils/exceptions.py`
# user                      {'login': 'mariosasko', 'id': 47462742, 'node_...
# labels                                                                   []
# state                                                                  open
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-11 18:28:00+00:00
# updated_at                                        2023-10-12 13:54:29+00:00
# closed_at                                                               NaT
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      I didn't notice the path while reviewing the P...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        8     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6295
# id                                                               1937362102
# node_id                                                 PR_kwDODunzps5cfiW8
# number                                                                 6295
# title                        Fix parquet columns argument in streaming mode
# user                      {'login': 'lhoestq', 'id': 42851186, 'node_id'...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2023-10-11 10:01:01+00:00
# updated_at                                        2023-10-11 16:30:24+00:00
# closed_at                                         2023-10-11 16:21:36+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      It was failing when there's a DatasetInfo with...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        9     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1937359605
# node_id                                                  I_kwDODunzps5zecL1
# number                                                                 6294
# title                     IndexError: Invalid key is out of bounds for s...
# user                      {'login': 'ZYM66', 'id': 61892155, 'node_id': ...
# labels                                                                   []
# state                                                                  open
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-11 09:59:38+00:00
# updated_at                                        2023-10-11 13:10:31+00:00
# closed_at                                                               NaT
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\n\nI am encountering an `...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   NaN
# pull_request                                                           None
#
#                           ...  \
# url                       ...
# repository_url            ...
# labels_url                ...
# comments_url              ...
# events_url                ...
# html_url                  ...
# id                        ...
# node_id                   ...
# number                    ...
# title                     ...
# user                      ...
# labels                    ...
# state                     ...
# locked                    ...
# assignee                  ...
# assignees                 ...
# milestone                 ...
# comments                  ...
# created_at                ...
# updated_at                ...
# closed_at                 ...
# author_association        ...
# active_lock_reason        ...
# body                      ...
# reactions                 ...
# timeline_url              ...
# performed_via_github_app  ...
# state_reason              ...
# draft                     ...
# pull_request              ...
#
#                                                                        6269  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                    https://github.com/huggingface/datasets/pull/10
# id                                                                603909327
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA2NjAxNzQ2
# number                                                                   10
# title                     Name json file "squad.json" instead of "squad....
# user                      {'login': 'patrickvonplaten', 'id': 23423619, ...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-21 11:04:28+00:00
# updated_at                                        2022-10-04 09:31:44+00:00
# closed_at                                         2020-04-21 20:48:06+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        6270  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/9
# id                                                                603894874
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA2NTkwMDQw
# number                                                                    9
# title                                                   [Clean up] Datasets
# user                      {'login': 'patrickvonplaten', 'id': 23423619, ...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2020-04-21 10:39:56+00:00
# updated_at                                        2022-10-04 09:31:42+00:00
# closed_at                                         2020-04-21 20:49:58+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      Clean up `nlp/datasets` folder. \r\n\r\nAs I u...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        6271  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/8
# id                                                                601783243
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA0OTg0NDUz
# number                                                                    8
# title                     Fix issue 6: error when the citation is missin...
# user                      {'login': 'jplu', 'id': 959590, 'node_id': 'MD...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-17 08:04:26+00:00
# updated_at                                        2020-04-29 09:27:11+00:00
# closed_at                                         2020-04-20 13:24:12+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        6272  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/7
# id                                                                601780534
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA0OTgyMzA2
# number                                                                    7
# title                                     Fix issue 5: allow empty datasets
# user                      {'login': 'jplu', 'id': 959590, 'node_id': 'MD...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-17 07:59:56+00:00
# updated_at                                        2020-04-29 09:27:13+00:00
# closed_at                                         2020-04-20 13:23:48+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
#                                                                        6273  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/6
# id                                                                600330836
# node_id                                            MDU6SXNzdWU2MDAzMzA4MzY=
# number                                                                    6
# title                     Error when citation is not given in the Datase...
# user                      {'login': 'jplu', 'id': 959590, 'node_id': 'MD...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-15 14:14:54+00:00
# updated_at                                        2020-04-29 09:23:22+00:00
# closed_at                                         2020-04-29 09:23:22+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      The following error is raised when the `citati...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        6274  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/5
# id                                                                600295889
# node_id                                            MDU6SXNzdWU2MDAyOTU4ODk=
# number                                                                    5
# title                                      ValueError when a split is empty
# user                      {'login': 'jplu', 'id': 959590, 'node_id': 'MD...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-15 13:25:13+00:00
# updated_at                                        2020-04-29 09:23:05+00:00
# closed_at                                         2020-04-29 09:23:05+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      When a split is empty either TEST, VALIDATION ...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        6275  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/4
# id                                                                600185417
# node_id                                            MDU6SXNzdWU2MDAxODU0MTc=
# number                                                                    4
# title                     [Feature] Keep the list of labels of a dataset...
# user                      {'login': 'jplu', 'id': 959590, 'node_id': 'MD...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  6
# created_at                                        2020-04-15 10:17:10+00:00
# updated_at                                        2020-07-08 16:59:46+00:00
# closed_at                                         2020-05-04 06:11:57+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      It would be useful to keep the list of the lab...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        6276  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/3
# id                                                                600180050
# node_id                                            MDU6SXNzdWU2MDAxODAwNTA=
# number                                                                    3
# title                                        [Feature] More dataset outputs
# user                      {'login': 'jplu', 'id': 959590, 'node_id': 'MD...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-15 10:08:14+00:00
# updated_at                                        2020-05-04 06:12:27+00:00
# closed_at                                         2020-05-04 06:12:27+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      Add the following dataset outputs:\r\n\r\n- Sp...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        6277  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/2
# id                                                                599767671
# node_id                                            MDU6SXNzdWU1OTk3Njc2NzE=
# number                                                                    2
# title                                         Issue to read a local dataset
# user                      {'login': 'jplu', 'id': 959590, 'node_id': 'MD...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  5
# created_at                                        2020-04-14 18:18:51+00:00
# updated_at                                        2020-05-11 18:55:23+00:00
# closed_at                                         2020-05-11 18:55:22+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      Hello,\r\n\r\nAs proposed by @thomwolf, I open...
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        6278
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/1
# id                                                                599457467
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDAzMDk1NDYw
# number                                                                    1
# title                                        changing nlp.bool to nlp.bool_
# user                      {'login': 'mariamabarham', 'id': 38249783, 'no...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-14 10:18:02+00:00
# updated_at                                        2022-10-04 09:31:40+00:00
# closed_at                                         2020-04-14 12:01:40+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body
# reactions                 {'url': 'https://api.github.com/repos/huggingf...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'url': 'https://api.github.com/repos/huggingf...
#
# [30 rows x 6279 columns]

# %%
issues_dataset = load_dataset("json", data_files="datasets-issues.jsonl", split="train")
issues_dataset
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/1468352 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/datasets/builder.py:1940, in ArrowBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, job_id)
#    1933     writer = writer_class(
#    1934         features=writer._features,
#    1935         path=fpath.replace("SSSSS", f"{shard_id:05d}").replace("JJJJJ", f"{job_id:05d}"),
#    (...)
#    1938         embed_local_files=embed_local_files,
#    1939     )
# -> 1940 writer.write_table(table)
#    1941 num_examples_progress_update += len(table)
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/datasets/arrow_writer.py:572, in ArrowWriter.write_table(self, pa_table, writer_batch_size)
#     571 pa_table = pa_table.combine_chunks()
# --> 572 pa_table = table_cast(pa_table, self._schema)
#     573 if self.embed_local_files:
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/datasets/table.py:2328, in table_cast(table, schema)
#    2327 if table.schema != schema:
# -> 2328     return cast_table_to_schema(table, schema)
#    2329 elif table.schema.metadata != schema.metadata:
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/datasets/table.py:2286, in cast_table_to_schema(table, schema)
#    2285 if sorted(table.column_names) != sorted(features):
# -> 2286     raise ValueError(f"Couldn't cast\n{table.schema}\nto\n{features}\nbecause column names don't match")
#    2287 arrays = [cast_array_to_feature(table[name], feature) for name, feature in features.items()]
#
# ValueError: Couldn't cast
# url: string
# repository_url: string
# labels_url: string
# comments_url: string
# events_url: string
# html_url: string
# id: int64
# node_id: string
# number: int64
# title: string
# user: struct<login: string, id: int64, node_id: string, avatar_url: string, gravatar_id: string, url: string, html_url: string, followers_url: string, following_url: string, gists_url: string, starred_url: string, subscriptions_url: string, organizations_url: string, repos_url: string, events_url: string, received_events_url: string, type: string, site_admin: bool>
#   child 0, login: string
#   child 1, id: int64
#   child 2, node_id: string
#   child 3, avatar_url: string
#   child 4, gravatar_id: string
#   child 5, url: string
#   child 6, html_url: string
#   child 7, followers_url: string
#   child 8, following_url: string
#   child 9, gists_url: string
#   child 10, starred_url: string
#   child 11, subscriptions_url: string
#   child 12, organizations_url: string
#   child 13, repos_url: string
#   child 14, events_url: string
#   child 15, received_events_url: string
#   child 16, type: string
#   child 17, site_admin: bool
# labels: list<item: struct<id: int64, node_id: string, url: string, name: string, color: string, default: bool, description: string>>
#   child 0, item: struct<id: int64, node_id: string, url: string, name: string, color: string, default: bool, description: string>
#       child 0, id: int64
#       child 1, node_id: string
#       child 2, url: string
#       child 3, name: string
#       child 4, color: string
#       child 5, default: bool
#       child 6, description: string
# state: string
# locked: bool
# assignee: struct<login: string, id: int64, node_id: string, avatar_url: string, gravatar_id: string, url: string, html_url: string, followers_url: string, following_url: string, gists_url: string, starred_url: string, subscriptions_url: string, organizations_url: string, repos_url: string, events_url: string, received_events_url: string, type: string, site_admin: bool>
#   child 0, login: string
#   child 1, id: int64
#   child 2, node_id: string
#   child 3, avatar_url: string
#   child 4, gravatar_id: string
#   child 5, url: string
#   child 6, html_url: string
#   child 7, followers_url: string
#   child 8, following_url: string
#   child 9, gists_url: string
#   child 10, starred_url: string
#   child 11, subscriptions_url: string
#   child 12, organizations_url: string
#   child 13, repos_url: string
#   child 14, events_url: string
#   child 15, received_events_url: string
#   child 16, type: string
#   child 17, site_admin: bool
# assignees: list<item: struct<login: string, id: int64, node_id: string, avatar_url: string, gravatar_id: string, url: string, html_url: string, followers_url: string, following_url: string, gists_url: string, starred_url: string, subscriptions_url: string, organizations_url: string, repos_url: string, events_url: string, received_events_url: string, type: string, site_admin: bool>>
#   child 0, item: struct<login: string, id: int64, node_id: string, avatar_url: string, gravatar_id: string, url: string, html_url: string, followers_url: string, following_url: string, gists_url: string, starred_url: string, subscriptions_url: string, organizations_url: string, repos_url: string, events_url: string, received_events_url: string, type: string, site_admin: bool>
#       child 0, login: string
#       child 1, id: int64
#       child 2, node_id: string
#       child 3, avatar_url: string
#       child 4, gravatar_id: string
#       child 5, url: string
#       child 6, html_url: string
#       child 7, followers_url: string
#       child 8, following_url: string
#       child 9, gists_url: string
#       child 10, starred_url: string
#       child 11, subscriptions_url: string
#       child 12, organizations_url: string
#       child 13, repos_url: string
#       child 14, events_url: string
#       child 15, received_events_url: string
#       child 16, type: string
#       child 17, site_admin: bool
# milestone: struct<url: string, html_url: string, labels_url: string, id: int64, node_id: string, number: int64, title: string, description: string, creator: struct<login: string, id: int64, node_id: string, avatar_url: string, gravatar_id: string, url: string, html_url: string, followers_url: string, following_url: string, gists_url: string, starred_url: string, subscriptions_url: string, organizations_url: string, repos_url: string, events_url: string, received_events_url: string, type: string, site_admin: bool>, open_issues: int64, closed_issues: int64, state: string, created_at: timestamp[s], updated_at: timestamp[s], due_on: null, closed_at: null>
#   child 0, url: string
#   child 1, html_url: string
#   child 2, labels_url: string
#   child 3, id: int64
#   child 4, node_id: string
#   child 5, number: int64
#   child 6, title: string
#   child 7, description: string
#   child 8, creator: struct<login: string, id: int64, node_id: string, avatar_url: string, gravatar_id: string, url: string, html_url: string, followers_url: string, following_url: string, gists_url: string, starred_url: string, subscriptions_url: string, organizations_url: string, repos_url: string, events_url: string, received_events_url: string, type: string, site_admin: bool>
#       child 0, login: string
#       child 1, id: int64
#       child 2, node_id: string
#       child 3, avatar_url: string
#       child 4, gravatar_id: string
#       child 5, url: string
#       child 6, html_url: string
#       child 7, followers_url: string
#       child 8, following_url: string
#       child 9, gists_url: string
#       child 10, starred_url: string
#       child 11, subscriptions_url: string
#       child 12, organizations_url: string
#       child 13, repos_url: string
#       child 14, events_url: string
#       child 15, received_events_url: string
#       child 16, type: string
#       child 17, site_admin: bool
#   child 9, open_issues: int64
#   child 10, closed_issues: int64
#   child 11, state: string
#   child 12, created_at: timestamp[s]
#   child 13, updated_at: timestamp[s]
#   child 14, due_on: null
#   child 15, closed_at: null
# comments: int64
# created_at: timestamp[s]
# updated_at: timestamp[s]
# closed_at: timestamp[s]
# author_association: string
# active_lock_reason: null
# body: string
# reactions: struct<url: string, total_count: int64, +1: int64, -1: int64, laugh: int64, hooray: int64, confused: int64, heart: int64, rocket: int64, eyes: int64>
#   child 0, url: string
#   child 1, total_count: int64
#   child 2, +1: int64
#   child 3, -1: int64
#   child 4, laugh: int64
#   child 5, hooray: int64
#   child 6, confused: int64
#   child 7, heart: int64
#   child 8, rocket: int64
#   child 9, eyes: int64
# timeline_url: string
# performed_via_github_app: null
# state_reason: string
# draft: bool
# pull_request: struct<url: string, html_url: string, diff_url: string, patch_url: string, merged_at: timestamp[s]>
#   child 0, url: string
#   child 1, html_url: string
#   child 2, diff_url: string
#   child 3, patch_url: string
#   child 4, merged_at: timestamp[s]
# to
# {'id': Value(dtype='string', id=None), 'data': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None)}
# because column names don't match
#
# The above exception was the direct cause of the following exception:
#
# DatasetGenerationError                    Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 issues_dataset = load_dataset("json", data_files="datasets-issues.jsonl", split="train")
#       2 issues_dataset
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/datasets/load.py:2136, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2133 try_from_hf_gcs = path not in _PACKAGED_DATASETS_MODULES
#    2135 # Download and prepare data
# -> 2136 builder_instance.download_and_prepare(
#    2137     download_config=download_config,
#    2138     download_mode=download_mode,
#    2139     verification_mode=verification_mode,
#    2140     try_from_hf_gcs=try_from_hf_gcs,
#    2141     num_proc=num_proc,
#    2142     storage_options=storage_options,
#    2143 )
#    2145 # Build dataset for splits
#    2146 keep_in_memory = (
#    2147     keep_in_memory if keep_in_memory is not None else is_small_dataset(builder_instance.info.dataset_size)
#    2148 )
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/datasets/builder.py:954, in DatasetBuilder.download_and_prepare(self, output_dir, download_config, download_mode, verification_mode, ignore_verifications, try_from_hf_gcs, dl_manager, base_path, use_auth_token, file_format, max_shard_size, num_proc, storage_options, **download_and_prepare_kwargs)
#     952     if num_proc is not None:
#     953         prepare_split_kwargs["num_proc"] = num_proc
# --> 954     self._download_and_prepare(
#     955         dl_manager=dl_manager,
#     956         verification_mode=verification_mode,
#     957         **prepare_split_kwargs,
#     958         **download_and_prepare_kwargs,
#     959     )
#     960 # Sync info
#     961 self.info.dataset_size = sum(split.num_bytes for split in self.info.splits.values())
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/datasets/builder.py:1049, in DatasetBuilder._download_and_prepare(self, dl_manager, verification_mode, **prepare_split_kwargs)
#    1045 split_dict.add(split_generator.split_info)
#    1047 try:
#    1048     # Prepare split will record examples associated to the split
# -> 1049     self._prepare_split(split_generator, **prepare_split_kwargs)
#    1050 except OSError as e:
#    1051     raise OSError(
#    1052         "Cannot find data file. "
#    1053         + (self.manual_download_instructions or "")
#    1054         + "\nOriginal error:\n"
#    1055         + str(e)
#    1056     ) from None
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/datasets/builder.py:1813, in ArrowBasedBuilder._prepare_split(self, split_generator, file_format, num_proc, max_shard_size)
#    1811 job_id = 0
#    1812 with pbar:
# -> 1813     for job_id, done, content in self._prepare_split_single(
#    1814         gen_kwargs=gen_kwargs, job_id=job_id, **_prepare_split_args
#    1815     ):
#    1816         if done:
#    1817             result = content
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/datasets/builder.py:1958, in ArrowBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, job_id)
#    1956     if isinstance(e, SchemaInferenceError) and e.__context__ is not None:
#    1957         e = e.__context__
# -> 1958     raise DatasetGenerationError("An error occurred while generating the dataset") from e
#    1960 yield job_id, True, (total_num_examples, total_num_bytes, writer._features, num_shards, shard_lengths)
#
# DatasetGenerationError: An error occurred while generating the dataset

# %% [markdown]
# It seems there is an issue with `load_dataset`: https://github.com/huggingface/datasets/issues/5422

# %% [markdown]
# Therefore lets use the suggestion here https://github.com/huggingface/datasets/issues/5422#issuecomment-1718035537

# %%
from datasets import Dataset
issues_dataset = Dataset.from_pandas(df)
issues_dataset
# Out:
# Dataset({
#     features: ['url', 'repository_url', 'labels_url', 'comments_url', 'events_url', 'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels', 'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments', 'created_at', 'updated_at', 'closed_at', 'author_association', 'active_lock_reason', 'body', 'reactions', 'timeline_url', 'performed_via_github_app', 'state_reason', 'draft', 'pull_request'],
#     num_rows: 6279
# })

# %%
sample = issues_dataset.shuffle(seed=666).select(range(3))

# %%
for url, pr in zip(sample['html_url'], sample['pull_request']):
    print(f">> URL: {url}")
    print(f">> Pull request: {pr}\n")
# Out:
# >> URL: https://github.com/huggingface/datasets/issues/1965
# >> Pull request: None
#
# >> URL: https://github.com/huggingface/datasets/pull/3472
# >> Pull request: {'diff_url': 'https://github.com/huggingface/datasets/pull/3472.diff', 'html_url': 'https://github.com/huggingface/datasets/pull/3472', 'merged_at': '2021-12-22T16:52:52Z', 'patch_url': 'https://github.com/huggingface/datasets/pull/3472.patch', 'url': 'https://api.github.com/repos/huggingface/datasets/pulls/3472'}
#
# >> URL: https://github.com/huggingface/datasets/pull/892
# >> Pull request: {'diff_url': 'https://github.com/huggingface/datasets/pull/892.diff', 'html_url': 'https://github.com/huggingface/datasets/pull/892', 'merged_at': '2020-11-27T18:08:44Z', 'patch_url': 'https://github.com/huggingface/datasets/pull/892.patch', 'url': 'https://api.github.com/repos/huggingface/datasets/pulls/892'}

# %%
issues_dataset = issues_dataset.map(
    lambda x: {"is_pull_request": False if x["pull_request"] is None else True}
)
# Out:
# Map:   0%|          | 0/6279 [00:00<?, ? examples/s]

# %%
issues_dataset_closed = issues_dataset.filter(lambda x: x["is_pull_request"] == False and x['state'] == 'closed')
# Out:
# Filter:   0%|          | 0/6279 [00:00<?, ? examples/s]

# %%
issues_dataset_closed.set_format("pandas")

# %%
issues_dataset_closed
# Out:
# Dataset({
#     features: ['url', 'repository_url', 'labels_url', 'comments_url', 'events_url', 'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels', 'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments', 'created_at', 'updated_at', 'closed_at', 'author_association', 'active_lock_reason', 'body', 'reactions', 'timeline_url', 'performed_via_github_app', 'state_reason', 'draft', 'pull_request', 'is_pull_request'],
#     num_rows: 1946
# })

# %%
issues_dataset_closed_df = issues_dataset_closed[:]

# %%
issues_dataset_closed_df.transpose().head(30)
# Out:
#                                                                        0     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1939649238
# node_id                                                  I_kwDODunzps5znLLW
# number                                                                 6299
# title                                     Support for newer versions of JAX
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                    [{'color': 'a2eeef', 'default': True, 'descrip...
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-10-12 10:03:46+00:00
# updated_at                                        2023-10-12 16:28:59+00:00
# closed_at                                         2023-10-12 16:28:59+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Feature request\r\n\r\nHi,\r\n\r\nI like y...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1937238047
# node_id                                                  I_kwDODunzps5zd-gf
# number                                                                 6293
# title                     Choose columns to stream parquet data in strea...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                    [{'color': 'd73a4a', 'default': True, 'descrip...
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-10-11 08:59:36+00:00
# updated_at                                        2023-10-11 16:21:38+00:00
# closed_at                                         2023-10-11 16:21:38+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      Currently passing columns= to load_dataset in ...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        2     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1936129871
# node_id                                                  I_kwDODunzps5zZv9P
# number                                                                 6291
# title                     Casting type from Array2D int to Array2D float...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-10 20:10:10+00:00
# updated_at                                        2023-10-13 13:45:31+00:00
# closed_at                                         2023-10-13 13:45:31+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\r\n\r\nI am on a school p...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        3     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1932758192
# node_id                                                  I_kwDODunzps5zM4yw
# number                                                                 6287
# title                                          map() not recognizing "text"
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-09 10:27:30+00:00
# updated_at                                        2023-10-11 20:28:45+00:00
# closed_at                                         2023-10-11 20:28:45+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\n\nThe [map() documentati...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        4     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1929551712
# node_id                                                  I_kwDODunzps5zAp9g
# number                                                                 6284
# title                     Add Belebele multiple-choice machine reading c...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                    [{'color': 'a2eeef', 'default': True, 'descrip...
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-06 06:58:03+00:00
# updated_at                                        2023-10-06 13:26:51+00:00
# closed_at                                         2023-10-06 13:26:51+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Feature request\n\nBelebele is a multiple-...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        5     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1927044546
# node_id                                                  I_kwDODunzps5y3F3C
# number                                                                 6277
# title                     FileNotFoundError: Couldn't find a module scri...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-04 22:01:25+00:00
# updated_at                                        2023-10-08 17:05:46+00:00
# closed_at                                         2023-10-08 17:05:46+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\n\nI'm encountering a "Fi...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        6     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1921354680
# node_id                                                  I_kwDODunzps5yhYu4
# number                                                                 6275
# title                                    Would like to Contribute a dataset
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-02 07:00:21+00:00
# updated_at                                        2023-10-10 16:27:54+00:00
# closed_at                                         2023-10-10 16:27:54+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      I have a dataset of 2500 images that can be us...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        7     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1921036328
# node_id                                                  I_kwDODunzps5ygLAo
# number                                                                 6274
# title                     FileNotFoundError for dataset with multiple bu...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2023-10-01 23:45:56+00:00
# updated_at                                        2023-10-02 20:09:38+00:00
# closed_at                                         2023-10-02 20:09:38+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\n\nWhen there is only one...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        8     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1920329373
# node_id                                                  I_kwDODunzps5ydead
# number                                                                 6270
# title                     Dataset.from_generator raises with sharded gen...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  6
# created_at                                        2023-09-30 16:50:06+00:00
# updated_at                                        2023-10-11 20:29:12+00:00
# closed_at                                         2023-10-11 20:29:11+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      ### Describe the bug\n\nAccording to the docs ...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        9     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                               1914951043
# node_id                                                  I_kwDODunzps5yI9WD
# number                                                                 6263
# title                     CI is broken: ImportError: cannot import name ...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                    [{'color': 'd73a4a', 'default': True, 'descrip...
# state                                                                closed
# locked                                                                False
# assignee                  {'avatar_url': 'https://avatars.githubusercont...
# assignees                 [{'avatar_url': 'https://avatars.githubusercon...
# milestone                                                              None
# comments                                                                  0
# created_at                                        2023-09-27 08:12:05+00:00
# updated_at                                        2023-09-27 08:36:40+00:00
# closed_at                                         2023-09-27 08:36:40+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      Python 3.10 CI is broken for `test_py310`.\r\n...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                           ...  \
# url                       ...
# repository_url            ...
# labels_url                ...
# comments_url              ...
# events_url                ...
# html_url                  ...
# id                        ...
# node_id                   ...
# number                    ...
# title                     ...
# user                      ...
# labels                    ...
# state                     ...
# locked                    ...
# assignee                  ...
# assignees                 ...
# milestone                 ...
# comments                  ...
# created_at                ...
# updated_at                ...
# closed_at                 ...
# author_association        ...
# active_lock_reason        ...
# body                      ...
# reactions                 ...
# timeline_url              ...
# performed_via_github_app  ...
# state_reason              ...
# draft                     ...
# pull_request              ...
#
#                                                                        1936  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                                618632573
# node_id                                            MDU6SXNzdWU2MTg2MzI1NzM=
# number                                                                  117
# title                          ❓ How to remove specific rows of a dataset ?
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  4
# created_at                                        2020-05-15 01:25:06+00:00
# updated_at                                        2022-07-15 08:36:44+00:00
# closed_at                                         2020-05-15 07:04:32+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      I saw on the [example notebook](https://colab....
# reactions                 {'+1': 1, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1937  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                                618628264
# node_id                                            MDU6SXNzdWU2MTg2MjgyNjQ=
# number                                                                  116
# title                     🐛 Trying to use ROUGE metric : pyarrow.lib.Arr...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                    [{'color': '25b21e', 'default': False, 'descri...
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  5
# created_at                                        2020-05-15 01:12:06+00:00
# updated_at                                        2020-05-28 23:43:07+00:00
# closed_at                                         2020-05-28 23:43:07+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      I'm trying to use rouge metric.\r\n\r\nI have ...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1938  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                                618615855
# node_id                                            MDU6SXNzdWU2MTg2MTU4NTU=
# number                                                                  115
# title                     AttributeError: 'dict' object has no attribute...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                  {'avatar_url': 'https://avatars.githubusercont...
# assignees                 [{'avatar_url': 'https://avatars.githubusercon...
# milestone                                                              None
# comments                                                                  2
# created_at                                        2020-05-15 00:29:47+00:00
# updated_at                                        2020-05-17 13:11:00+00:00
# closed_at                                         2020-05-17 13:11:00+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      I'm trying to access the information of CNN/DM...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1939  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues...
# id                                                                618611310
# node_id                                            MDU6SXNzdWU2MTg2MTEzMTA=
# number                                                                  114
# title                                         Couldn't reach CNN/DM dataset
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2020-05-15 00:16:17+00:00
# updated_at                                        2020-05-15 00:19:52+00:00
# closed_at                                         2020-05-15 00:19:51+00:00
# author_association                                                     NONE
# active_lock_reason                                                      NaN
# body                      I can't get CNN / DailyMail dataset.\r\n\r\n``...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1940  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/issues/38
# id                                                                611677656
# node_id                                            MDU6SXNzdWU2MTE2Nzc2NTY=
# number                                                                   38
# title                                   [Checksums] Error for some datasets
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                  {'avatar_url': 'https://avatars.githubusercont...
# assignees                 [{'avatar_url': 'https://avatars.githubusercon...
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-05-04 08:00:16+00:00
# updated_at                                        2020-05-04 09:48:20+00:00
# closed_at                                         2020-05-04 09:48:20+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      The checksums command works very nicely for `s...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1941  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/6
# id                                                                600330836
# node_id                                            MDU6SXNzdWU2MDAzMzA4MzY=
# number                                                                    6
# title                     Error when citation is not given in the Datase...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-15 14:14:54+00:00
# updated_at                                        2020-04-29 09:23:22+00:00
# closed_at                                         2020-04-29 09:23:22+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      The following error is raised when the `citati...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1942  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/5
# id                                                                600295889
# node_id                                            MDU6SXNzdWU2MDAyOTU4ODk=
# number                                                                    5
# title                                      ValueError when a split is empty
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-15 13:25:13+00:00
# updated_at                                        2020-04-29 09:23:05+00:00
# closed_at                                         2020-04-29 09:23:05+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      When a split is empty either TEST, VALIDATION ...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1943  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/4
# id                                                                600185417
# node_id                                            MDU6SXNzdWU2MDAxODU0MTc=
# number                                                                    4
# title                     [Feature] Keep the list of labels of a dataset...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  6
# created_at                                        2020-04-15 10:17:10+00:00
# updated_at                                        2020-07-08 16:59:46+00:00
# closed_at                                         2020-05-04 06:11:57+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      It would be useful to keep the list of the lab...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1944  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/3
# id                                                                600180050
# node_id                                            MDU6SXNzdWU2MDAxODAwNTA=
# number                                                                    3
# title                                        [Feature] More dataset outputs
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-15 10:08:14+00:00
# updated_at                                        2020-05-04 06:12:27+00:00
# closed_at                                         2020-05-04 06:12:27+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      Add the following dataset outputs:\r\n\r\n- Sp...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
#                                                                        1945
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                   https://github.com/huggingface/datasets/issues/2
# id                                                                599767671
# node_id                                            MDU6SXNzdWU1OTk3Njc2NzE=
# number                                                                    2
# title                                         Issue to read a local dataset
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  5
# created_at                                        2020-04-14 18:18:51+00:00
# updated_at                                        2020-05-11 18:55:23+00:00
# closed_at                                         2020-05-11 18:55:22+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      Hello,\r\n\r\nAs proposed by @thomwolf, I open...
# reactions                 {'+1': 1, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                      completed
# draft                                                                   NaN
# pull_request                                                           None
#
# [30 rows x 1946 columns]

# %%
(issues_dataset_closed_df['closed_at'] - issues_dataset_closed_df['created_at']).mean()
# Out:
# Timedelta('77 days 06:27:28.649023638')

# %%
(issues_dataset_closed_df['closed_at'] - issues_dataset_closed_df['created_at']).median()
# Out:
# Timedelta('5 days 17:36:28.500000')

# %%
(issues_dataset_closed_df['closed_at'] - issues_dataset_closed_df['created_at']).describe()
# Out:
# count                           1946
# mean      77 days 06:27:28.649023638
# std      175 days 16:54:51.213781774
# min                  0 days 00:00:18
# 25%           0 days 20:17:49.500000
# 50%           5 days 17:36:28.500000
# 75%                 34 days 16:36:16
# max               1081 days 08:05:48
# dtype: object

# %%
pull_request_dataset = issues_dataset.filter(lambda x: x["is_pull_request"] == True and x['state'] == 'closed')
# Out:
# Filter:   0%|          | 0/6279 [00:00<?, ? examples/s]

# %%
pull_request_dataset.set_format("pandas")
pull_request_df = pull_request_dataset[:]

# %%
pull_request_df.transpose().head(30)
# Out:
#                                                                        0     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6301
# id                                                               1940183999
# node_id                                                 PR_kwDODunzps5cpPVh
# number                                                                 6301
# title                                    Unpin `tensorflow` maximum version
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2023-10-12 14:58:07+00:00
# updated_at                                        2023-10-12 15:58:20+00:00
# closed_at                                         2023-10-12 15:49:54+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                         Removes the temporary pin introduced in #6264
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        1     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6300
# id                                                               1940153432
# node_id                                                 PR_kwDODunzps5cpIoG
# number                                                                 6300
# title                                           Unpin `jax` maximum version
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  6
# created_at                                        2023-10-12 14:42:40+00:00
# updated_at                                        2023-10-12 16:37:55+00:00
# closed_at                                         2023-10-12 16:28:57+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                                                 fix #6299\r\nfix #6202
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        2     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6298
# id                                                               1938797389
# node_id                                                 PR_kwDODunzps5ckg6j
# number                                                                 6298
# title                                               Doc readme improvements
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-11 21:51:12+00:00
# updated_at                                        2023-10-12 12:47:15+00:00
# closed_at                                         2023-10-12 12:38:19+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      Changes in the doc READMe:\r\n* adds two new s...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6297
# id                                                               1938752707
# node_id                                                 PR_kwDODunzps5ckXBa
# number                                                                 6297
# title                                                      Fix ArrayXD cast
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-11 21:14:59+00:00
# updated_at                                        2023-10-13 13:54:00+00:00
# closed_at                                         2023-10-13 13:45:30+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                                                             Fix #6291
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        4     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6295
# id                                                               1937362102
# node_id                                                 PR_kwDODunzps5cfiW8
# number                                                                 6295
# title                        Fix parquet columns argument in streaming mode
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2023-10-11 10:01:01+00:00
# updated_at                                        2023-10-11 16:30:24+00:00
# closed_at                                         2023-10-11 16:21:36+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      It was failing when there's a DatasetInfo with...
# reactions                 {'+1': 1, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        5     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6289
# id                                                               1935628506
# node_id                                                 PR_kwDODunzps5cZiay
# number                                                                 6289
# title                                                   testing doc-builder
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-10 15:17:29+00:00
# updated_at                                        2023-10-13 08:57:14+00:00
# closed_at                                         2023-10-13 08:56:48+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      testing https://github.com/huggingface/doc-bui...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        6     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6286
# id                                                               1932640128
# node_id                                                 PR_kwDODunzps5cPKNK
# number                                                                 6286
# title                                            Create DefunctDatasetError
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-09 09:23:23+00:00
# updated_at                                        2023-10-10 07:13:22+00:00
# closed_at                                         2023-10-10 07:03:04+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      Create `DefunctDatasetError` as a specific err...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        7     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6281
# id                                                               1928456959
# node_id                                                 PR_kwDODunzps5cBQPd
# number                                                                 6281
# title                       Improve documentation of dataset.from_generator
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  2
# created_at                                        2023-10-05 14:34:49+00:00
# updated_at                                        2023-10-05 19:09:07+00:00
# closed_at                                         2023-10-05 18:57:41+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      Improve documentation to clarify sharding beha...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        8     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6278
# id                                                               1927957877
# node_id                                                 PR_kwDODunzps5b_iKb
# number                                                                 6278
# title                                              No data files duplicates
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  4
# created_at                                        2023-10-05 10:31:58+00:00
# updated_at                                        2023-10-05 14:43:17+00:00
# closed_at                                         2023-10-05 14:43:17+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      I added a new DataFilesSet class to disallow d...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   1.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        9     \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                  https://github.com/huggingface/datasets/pull/6265
# id                                                               1915651566
# node_id                                                 PR_kwDODunzps5bWDfc
# number                                                                 6265
# title                     Remove `apache_beam` import in `BeamBasedBuild...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  4
# created_at                                        2023-09-27 13:56:34+00:00
# updated_at                                        2023-09-28 18:34:02+00:00
# closed_at                                         2023-09-28 18:23:35+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body                      ... to avoid an `ImportError` raised in `BeamB...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                           ...  \
# url                       ...
# repository_url            ...
# labels_url                ...
# comments_url              ...
# events_url                ...
# html_url                  ...
# id                        ...
# node_id                   ...
# number                    ...
# title                     ...
# user                      ...
# labels                    ...
# state                     ...
# locked                    ...
# assignee                  ...
# assignees                 ...
# milestone                 ...
# comments                  ...
# created_at                ...
# updated_at                ...
# closed_at                 ...
# author_association        ...
# active_lock_reason        ...
# body                      ...
# reactions                 ...
# timeline_url              ...
# performed_via_github_app  ...
# state_reason              ...
# draft                     ...
# pull_request              ...
#
#                                                                        3696  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                    https://github.com/huggingface/datasets/pull/15
# id                                                                604906708
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA3NDEwOTk3
# number                                                                   15
# title                     [Tests] General Test Design for all dataset sc...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                 10
# created_at                                        2020-04-22 16:46:01+00:00
# updated_at                                        2022-10-04 09:31:54+00:00
# closed_at                                         2020-04-27 14:48:02+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      The general idea is similar to how testing is ...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3697  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                    https://github.com/huggingface/datasets/pull/14
# id                                                                604761315
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA3MjkzNjU5
# number                                                                   14
# title                       [Download] Only create dir if not already exist
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-22 13:32:51+00:00
# updated_at                                        2022-10-04 09:31:50+00:00
# closed_at                                         2020-04-23 08:27:33+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      This was quite annoying to find out :D. \r\nSo...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3698  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                    https://github.com/huggingface/datasets/pull/13
# id                                                                604547951
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA3MTIxMjkw
# number                                                                   13
# title                                                          [Make style]
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-22 08:10:06+00:00
# updated_at                                        2022-10-04 09:31:51+00:00
# closed_at                                         2020-04-23 13:02:22+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      Added Makefile and applied make style to all. ...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3699  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                    https://github.com/huggingface/datasets/pull/12
# id                                                                604518583
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA3MDk3MzA4
# number                                                                   12
# title                     [Map Function] add assert statement if map fun...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  3
# created_at                                        2020-04-22 07:21:24+00:00
# updated_at                                        2022-10-04 09:31:53+00:00
# closed_at                                         2020-04-24 06:29:03+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      IMO, if a function is provided that is not a p...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3700  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                    https://github.com/huggingface/datasets/pull/11
# id                                                                603921624
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA2NjExODk2
# number                                                                   11
# title                     [Convert TFDS to HFDS] Extend script to also a...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-21 11:25:33+00:00
# updated_at                                        2022-10-04 09:31:46+00:00
# closed_at                                         2020-04-21 20:47:00+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      Adds another argument to be able to convert on...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3701  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                    https://github.com/huggingface/datasets/pull/10
# id                                                                603909327
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA2NjAxNzQ2
# number                                                                   10
# title                     Name json file "squad.json" instead of "squad....
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-21 11:04:28+00:00
# updated_at                                        2022-10-04 09:31:44+00:00
# closed_at                                         2020-04-21 20:48:06+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3702  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/9
# id                                                                603894874
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA2NTkwMDQw
# number                                                                    9
# title                                                   [Clean up] Datasets
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  1
# created_at                                        2020-04-21 10:39:56+00:00
# updated_at                                        2022-10-04 09:31:42+00:00
# closed_at                                         2020-04-21 20:49:58+00:00
# author_association                                                   MEMBER
# active_lock_reason                                                      NaN
# body                      Clean up `nlp/datasets` folder. \r\n\r\nAs I u...
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3703  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/8
# id                                                                601783243
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA0OTg0NDUz
# number                                                                    8
# title                     Fix issue 6: error when the citation is missin...
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-17 08:04:26+00:00
# updated_at                                        2020-04-29 09:27:11+00:00
# closed_at                                         2020-04-20 13:24:12+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3704  \
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/7
# id                                                                601780534
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDA0OTgyMzA2
# number                                                                    7
# title                                     Fix issue 5: allow empty datasets
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-17 07:59:56+00:00
# updated_at                                        2020-04-29 09:27:13+00:00
# closed_at                                         2020-04-20 13:23:48+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
#                                                                        3705
# url                       https://api.github.com/repos/huggingface/datas...
# repository_url            https://api.github.com/repos/huggingface/datasets
# labels_url                https://api.github.com/repos/huggingface/datas...
# comments_url              https://api.github.com/repos/huggingface/datas...
# events_url                https://api.github.com/repos/huggingface/datas...
# html_url                     https://github.com/huggingface/datasets/pull/1
# id                                                                599457467
# node_id                                    MDExOlB1bGxSZXF1ZXN0NDAzMDk1NDYw
# number                                                                    1
# title                                        changing nlp.bool to nlp.bool_
# user                      {'avatar_url': 'https://avatars.githubusercont...
# labels                                                                   []
# state                                                                closed
# locked                                                                False
# assignee                                                               None
# assignees                                                                []
# milestone                                                              None
# comments                                                                  0
# created_at                                        2020-04-14 10:18:02+00:00
# updated_at                                        2022-10-04 09:31:40+00:00
# closed_at                                         2020-04-14 12:01:40+00:00
# author_association                                              CONTRIBUTOR
# active_lock_reason                                                      NaN
# body
# reactions                 {'+1': 0, '-1': 0, 'confused': 0, 'eyes': 0, '...
# timeline_url              https://api.github.com/repos/huggingface/datas...
# performed_via_github_app                                                NaN
# state_reason                                                           None
# draft                                                                   0.0
# pull_request              {'diff_url': 'https://github.com/huggingface/d...
#
# [30 rows x 3706 columns]

# %%
(pull_request_df['closed_at'] - pull_request_df['created_at']).describe()
# Out:
# count                          3706
# mean     15 days 03:06:04.498920669
# std      71 days 14:28:05.141772524
# min                 0 days 00:00:06
# 25%          0 days 03:16:48.500000
# 50%          1 days 04:23:30.500000
# 75%                 5 days 05:20:17
# max               984 days 16:05:16
# dtype: object

# %%
issue_number = 6301
url = f"https://api.github.com/repos/huggingface/datasets/issues/{issue_number}/comments"
response = requests.get(url, headers=headers)

# %%
response.json()
# Out:
# [{'url': 'https://api.github.com/repos/huggingface/datasets/issues/comments/1759794986',
#   'html_url': 'https://github.com/huggingface/datasets/pull/6301#issuecomment-1759794986',
#   'issue_url': 'https://api.github.com/repos/huggingface/datasets/issues/6301',
#   'id': 1759794986,
#   'node_id': 'IC_kwDODunzps5o5Fcq',
#   'user': {'login': 'github-actions[bot]',
#    'id': 41898282,
#    'node_id': 'MDM6Qm90NDE4OTgyODI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#    'html_url': 'https://github.com/apps/github-actions',
#    'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#    'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#    'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#    'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#    'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#    'type': 'Bot',
#    'site_admin': False},
#   'created_at': '2023-10-12T15:06:33Z',
#   'updated_at': '2023-10-12T15:06:33Z',
#   'author_association': 'NONE',
#   'body': '<details>\n<summary>Show benchmarks</summary>\n\nPyArrow==8.0.0\n\n<details>\n<summary>Show updated benchmarks!</summary>\n\n### Benchmark: benchmark_array_xd.json\n\n| metric | read_batch_formatted_as_numpy after write_array2d | read_batch_formatted_as_numpy after write_flattened_sequence | read_batch_formatted_as_numpy after write_nested_sequence | read_batch_unformated after write_array2d | read_batch_unformated after write_flattened_sequence | read_batch_unformated after write_nested_sequence | read_col_formatted_as_numpy after write_array2d | read_col_formatted_as_numpy after write_flattened_sequence | read_col_formatted_as_numpy after write_nested_sequence | read_col_unformated after write_array2d | read_col_unformated after write_flattened_sequence | read_col_unformated after write_nested_sequence | read_formatted_as_numpy after write_array2d | read_formatted_as_numpy after write_flattened_sequence | read_formatted_as_numpy after write_nested_sequence | read_unformated after write_array2d | read_unformated after write_flattened_sequence | read_unformated after write_nested_sequence | write_array2d | write_flattened_sequence | write_nested_sequence |\n|--------|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|\n| new / old (diff) | 0.006663 / 0.011353 (-0.004690) | 0.004091 / 0.011008 (-0.006918) | 0.084954 / 0.038508 (0.046445) | 0.071869 / 0.023109 (0.048760) | 0.314706 / 0.275898 (0.038808) | 0.352794 / 0.323480 (0.029314) | 0.004027 / 0.007986 (-0.003959) | 0.003371 / 0.004328 (-0.000957) | 0.065456 / 0.004250 (0.061205) | 0.055828 / 0.037052 (0.018775) | 0.316502 / 0.258489 (0.058013) | 0.377979 / 0.293841 (0.084138) | 0.030870 / 0.128546 (-0.097676) | 0.008616 / 0.075646 (-0.067030) | 0.288625 / 0.419271 (-0.130646) | 0.052314 / 0.043533 (0.008781) | 0.322725 / 0.255139 (0.067586) | 0.351810 / 0.283200 (0.068611) | 0.025726 / 0.141683 (-0.115957) | 1.439308 / 1.452155 (-0.012847) | 1.524484 / 1.492716 (0.031768) |\n\n### Benchmark: benchmark_getitem\\_100B.json\n\n| metric | get_batch_of\\_1024\\_random_rows | get_batch_of\\_1024\\_rows | get_first_row | get_last_row |\n|--------|---|---|---|---|\n| new / old (diff) | 0.235212 / 0.018006 (0.217206) | 0.444926 / 0.000490 (0.444437) | 0.009887 / 0.000200 (0.009687) | 0.000402 / 0.000054 (0.000347) |\n\n### Benchmark: benchmark_indices_mapping.json\n\n| metric | select | shard | shuffle | sort | train_test_split |\n|--------|---|---|---|---|---|\n| new / old (diff) | 0.028956 / 0.037411 (-0.008455) | 0.084401 / 0.014526 (0.069875) | 0.339686 / 0.176557 (0.163130) | 0.186785 / 0.737135 (-0.550350) | 0.195017 / 0.296338 (-0.101322) |\n\n### Benchmark: benchmark_iterating.json\n\n| metric | read 5000 | read 50000 | read_batch 50000 10 | read_batch 50000 100 | read_batch 50000 1000 | read_formatted numpy 5000 | read_formatted pandas 5000 | read_formatted tensorflow 5000 | read_formatted torch 5000 | read_formatted_batch numpy 5000 10 | read_formatted_batch numpy 5000 1000 | shuffled read 5000 | shuffled read 50000 | shuffled read_batch 50000 10 | shuffled read_batch 50000 100 | shuffled read_batch 50000 1000 | shuffled read_formatted numpy 5000 | shuffled read_formatted_batch numpy 5000 10 | shuffled read_formatted_batch numpy 5000 1000 |\n|--------|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|\n| new / old (diff) | 0.405480 / 0.215209 (0.190271) | 4.024315 / 2.077655 (1.946661) | 2.056398 / 1.504120 (0.552278) | 1.912099 / 1.541195 (0.370904) | 1.950119 / 1.468490 (0.481629) | 0.486071 / 4.584777 (-4.098706) | 3.578501 / 3.745712 (-0.167211) | 3.268980 / 5.269862 (-2.000881) | 2.018114 / 4.565676 (-2.547563) | 0.057440 / 0.424275 (-0.366835) | 0.007281 / 0.007607 (-0.000326) | 0.474760 / 0.226044 (0.248716) | 4.746908 / 2.268929 (2.477979) | 2.550111 / 55.444624 (-52.894513) | 2.171932 / 6.876477 (-4.704544) | 2.392235 / 2.142072 (0.250162) | 0.585940 / 4.805227 (-4.219287) | 0.136445 / 6.500664 ...
#   'reactions': {'url': 'https://api.github.com/repos/huggingface/datasets/issues/comments/1759794986/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/huggingface/datasets/issues/comments/1759889437',
#   'html_url': 'https://github.com/huggingface/datasets/pull/6301#issuecomment-1759889437',
#   'issue_url': 'https://api.github.com/repos/huggingface/datasets/issues/6301',
#   'id': 1759889437,
#   'node_id': 'IC_kwDODunzps5o5cgd',
#   'user': {'login': 'mariosasko',
#    'id': 47462742,
#    'node_id': 'MDQ6VXNlcjQ3NDYyNzQy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47462742?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mariosasko',
#    'html_url': 'https://github.com/mariosasko',
#    'followers_url': 'https://api.github.com/users/mariosasko/followers',
#    'following_url': 'https://api.github.com/users/mariosasko/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mariosasko/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mariosasko/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mariosasko/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mariosasko/orgs',
#    'repos_url': 'https://api.github.com/users/mariosasko/repos',
#    'events_url': 'https://api.github.com/users/mariosasko/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mariosasko/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'created_at': '2023-10-12T15:49:42Z',
#   'updated_at': '2023-10-12T15:49:42Z',
#   'author_association': 'CONTRIBUTOR',
#   'body': 'CI failures are unrelated',
#   'reactions': {'url': 'https://api.github.com/repos/huggingface/datasets/issues/comments/1759889437/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/huggingface/datasets/issues/comments/1759908734',
#   'html_url': 'https://github.com/huggingface/datasets/pull/6301#issuecomment-1759908734',
#   'issue_url': 'https://api.github.com/repos/huggingface/datasets/issues/6301',
#   'id': 1759908734,
#   'node_id': 'IC_kwDODunzps5o5hN-',
#   'user': {'login': 'github-actions[bot]',
#    'id': 41898282,
#    'node_id': 'MDM6Qm90NDE4OTgyODI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#    'html_url': 'https://github.com/apps/github-actions',
#    'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#    'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#    'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#    'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#    'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#    'type': 'Bot',
#    'site_admin': False},
#   'created_at': '2023-10-12T15:58:19Z',
#   'updated_at': '2023-10-12T15:58:19Z',
#   'author_association': 'NONE',
#   'body': '<details>\n<summary>Show benchmarks</summary>\n\nPyArrow==8.0.0\n\n<details>\n<summary>Show updated benchmarks!</summary>\n\n### Benchmark: benchmark_array_xd.json\n\n| metric | read_batch_formatted_as_numpy after write_array2d | read_batch_formatted_as_numpy after write_flattened_sequence | read_batch_formatted_as_numpy after write_nested_sequence | read_batch_unformated after write_array2d | read_batch_unformated after write_flattened_sequence | read_batch_unformated after write_nested_sequence | read_col_formatted_as_numpy after write_array2d | read_col_formatted_as_numpy after write_flattened_sequence | read_col_formatted_as_numpy after write_nested_sequence | read_col_unformated after write_array2d | read_col_unformated after write_flattened_sequence | read_col_unformated after write_nested_sequence | read_formatted_as_numpy after write_array2d | read_formatted_as_numpy after write_flattened_sequence | read_formatted_as_numpy after write_nested_sequence | read_unformated after write_array2d | read_unformated after write_flattened_sequence | read_unformated after write_nested_sequence | write_array2d | write_flattened_sequence | write_nested_sequence |\n|--------|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|\n| new / old (diff) | 0.005815 / 0.011353 (-0.005538) | 0.003419 / 0.011008 (-0.007589) | 0.080286 / 0.038508 (0.041778) | 0.056487 / 0.023109 (0.033377) | 0.304414 / 0.275898 (0.028516) | 0.341039 / 0.323480 (0.017559) | 0.004392 / 0.007986 (-0.003594) | 0.002852 / 0.004328 (-0.001477) | 0.062339 / 0.004250 (0.058089) | 0.044683 / 0.037052 (0.007630) | 0.311651 / 0.258489 (0.053162) | 0.357249 / 0.293841 (0.063409) | 0.027300 / 0.128546 (-0.101246) | 0.007963 / 0.075646 (-0.067683) | 0.261948 / 0.419271 (-0.157323) | 0.044952 / 0.043533 (0.001419) | 0.309990 / 0.255139 (0.054851) | 0.340735 / 0.283200 (0.057536) | 0.020786 / 0.141683 (-0.120897) | 1.471378 / 1.452155 (0.019224) | 1.517260 / 1.492716 (0.024543) |\n\n### Benchmark: benchmark_getitem\\_100B.json\n\n| metric | get_batch_of\\_1024\\_random_rows | get_batch_of\\_1024\\_rows | get_first_row | get_last_row |\n|--------|---|---|---|---|\n| new / old (diff) | 0.245447 / 0.018006 (0.227441) | 0.418967 / 0.000490 (0.418477) | 0.007039 / 0.000200 (0.006840) | 0.000196 / 0.000054 (0.000142) |\n\n### Benchmark: benchmark_indices_mapping.json\n\n| metric | select | shard | shuffle | sort | train_test_split |\n|--------|---|---|---|---|---|\n| new / old (diff) | 0.022880 / 0.037411 (-0.014532) | 0.071862 / 0.014526 (0.057337) | 0.083009 / 0.176557 (-0.093547) | 0.143414 / 0.737135 (-0.593722) | 0.082896 / 0.296338 (-0.213442) |\n\n### Benchmark: benchmark_iterating.json\n\n| metric | read 5000 | read 50000 | read_batch 50000 10 | read_batch 50000 100 | read_batch 50000 1000 | read_formatted numpy 5000 | read_formatted pandas 5000 | read_formatted tensorflow 5000 | read_formatted torch 5000 | read_formatted_batch numpy 5000 10 | read_formatted_batch numpy 5000 1000 | shuffled read 5000 | shuffled read 50000 | shuffled read_batch 50000 10 | shuffled read_batch 50000 100 | shuffled read_batch 50000 1000 | shuffled read_formatted numpy 5000 | shuffled read_formatted_batch numpy 5000 10 | shuffled read_formatted_batch numpy 5000 1000 |\n|--------|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|\n| new / old (diff) | 0.390645 / 0.215209 (0.175436) | 3.888104 / 2.077655 (1.810450) | 1.859572 / 1.504120 (0.355452) | 1.683803 / 1.541195 (0.142608) | 1.697902 / 1.468490 (0.229412) | 0.499537 / 4.584777 (-4.085239) | 3.015832 / 3.745712 (-0.729881) | 2.805696 / 5.269862 (-2.464166) | 1.830408 / 4.565676 (-2.735268) | 0.058191 / 0.424275 (-0.366085) | 0.006357 / 0.007607 (-0.001250) | 0.462486 / 0.226044 (0.236442) | 4.634951 / 2.268929 (2.366022) | 2.309364 / 55.444624 (-53.135260) | 1.979521 / 6.876477 (-4.896956) | 2.080011 / 2.142072 (-0.062062) | 0.593086 / 4.805227 (-4.212141) | 0.124856 / 6.50066 ...
#   'reactions': {'url': 'https://api.github.com/repos/huggingface/datasets/issues/comments/1759908734/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'performed_via_github_app': None}]

# %%
def get_comments(issue_number):
    url = f"https://api.github.com/repos/huggingface/datasets/issues/{issue_number}/comments"
    response = requests.get(url, headers=headers)
    return [r['body'] for r in response.json()]

# %%
get_comments(2792)
# Out:
# ["@albertvillanova my tests are failing here:\r\n```\r\ndataset_name = 'gooaq'\r\n\r\n    def test_load_dataset(self, dataset_name):\r\n        configs = self.dataset_tester.load_all_configs(dataset_name, is_local=True)[:1]\r\n>       self.dataset_tester.check_load_dataset(dataset_name, configs, is_local=True, use_local_dummy_data=True)\r\n\r\ntests/test_dataset_common.py:234: \r\n_ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ \r\ntests/test_dataset_common.py:187: in check_load_dataset\r\n    self.parent.assertTrue(len(dataset[split]) > 0)\r\nE   AssertionError: False is not true\r\n```\r\nWhen I try loading dataset on local machine it works fine. Any suggestions on how can I avoid this error?",
#  'Thanks for the help, @albertvillanova! All tests are passing now.']

# %%
issues_with_comments_dataset = issues_dataset.map(
    lambda x: {"comments": get_comments(x["number"])}
)
# Out:
# Map:   0%|          | 0/6279 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/urllib3/connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/socket.py:954, in getaddrinfo(host, port, family, type, proto, flags)
#     953 addrlist = []
# --> 954 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/urllib3/connectionpool.py:491, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 491     raise new_e
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/urllib3/connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/urllib3/connection.py:611, in HTTPSConnection.connect(self)
#     610 sock: socket.socket | ssl.SSLSocket
# --> 611 self.sock = sock = self._new_conn()
#     612 server_hostname: str = self.host
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/urllib3/connection.py:210, in HTTPConnection._new_conn(self)
#     209 except socket.gaierror as e:
# --> 210     raise NameResolutionError(self.host, self, e) from e
#     211 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x129ba50d0>: Failed to resolve 'api.github.com' ([Errno 8] nodename nor servname provided, or not known)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/urllib3/connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/urllib3/util/retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /repos/huggingface/datasets/issues/1453/comments (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x129ba50d0>: Failed to resolve 'api.github.com' ([Errno 8] nodename nor servname provided, or not known)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 issues_with_comments_dataset = issues_dataset.map(
#       2     lambda x: {"comments": get_comments(x["number"])}
#       3 )
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/datasets/arrow_dataset.py:592, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     590     self: "Dataset" = kwargs.pop("self")
#     591 # apply actual function
# --> 592 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     593 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     594 for dataset in datasets:
#     595     # Remove task templates if a column mapping of the template is no longer valid
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/datasets/arrow_dataset.py:557, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     550 self_format = {
#     551     "type": self._format_type,
#     552     "format_kwargs": self._format_kwargs,
#     553     "columns": self._format_columns,
#     554     "output_all_columns": self._output_all_columns,
#     555 }
#     556 # apply actual function
# --> 557 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     558 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     559 # re-apply format to the output
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/datasets/arrow_dataset.py:3097, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3090 if transformed_dataset is None:
#    3091     with logging.tqdm(
#    3092         disable=not logging.is_progress_bar_enabled(),
#    3093         unit=" examples",
#    3094         total=pbar_total,
#    3095         desc=desc or "Map",
#    3096     ) as pbar:
# -> 3097         for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3098             if done:
#    3099                 shards_done += 1
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/datasets/arrow_dataset.py:3450, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3448 _time = time.time()
#    3449 for i, example in shard_iterable:
# -> 3450     example = apply_function_on_filtered_inputs(example, i, offset=offset)
#    3451     if update_data:
#    3452         if i == 0:
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/datasets/arrow_dataset.py:3353, in Dataset._map_single.<locals>.apply_function_on_filtered_inputs(pa_inputs, indices, check_same_num_examples, offset)
#    3351 if with_rank:
#    3352     additional_args += (rank,)
# -> 3353 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3354 if isinstance(processed_inputs, LazyDict):
#    3355     processed_inputs = {
#    3356         k: v for k, v in processed_inputs.data.items() if k not in processed_inputs.keys_to_format
#    3357     }
#
# Cell In[65], line 2, in <lambda>(x)
#       1 issues_with_comments_dataset = issues_dataset.map(
# ----> 2     lambda x: {"comments": get_comments(x["number"])}
#       3 )
#
# Cell In[63], line 3, in get_comments(issue_number)
#       1 def get_comments(issue_number):
#       2     url = f"https://api.github.com/repos/huggingface/datasets/issues/{issue_number}/comments"
# ----> 3     response = requests.get(url, headers=headers)
#       4     return [r['body'] for r in response.json()]
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/mambaforge/envs/transformers-course/lib/python3.9/site-packages/requests/adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /repos/huggingface/datasets/issues/1453/comments (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x129ba50d0>: Failed to resolve 'api.github.com' ([Errno 8] nodename nor servname provided, or not known)"))
